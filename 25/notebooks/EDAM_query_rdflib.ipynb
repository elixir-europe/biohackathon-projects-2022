# %% [markdown]
# ## Load EDAM from github

# %%
from rdflib import ConjunctiveGraph, Namespace
import pandas as pd
import numpy as np

print("Loading graph ...", end="")
g = ConjunctiveGraph()
g.parse('https://raw.githubusercontent.com/edamontology/edamontology/master/EDAM_dev.owl', format='xml')
#g.parse('../edamontology/EDAM_dev.owl', format='xml')
g.bind('edam', Namespace('http://edamontology.org#'))
print("done!")
print(str(len(g)) + ' triples in the EDAM triple store')
# Out:
# Loading graph ...done!
# 38256 triples in the EDAM triple store

# %% [markdown]
# ## query to get format without the *is_format_of* property

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT ?entity ?label ?property WHERE
{
  
    # ?entity rdfs:subClassOf+ edam:format_1915 .
    # ?entity rdfs:label ?label .

     VALUES ?property { edam:is_format_of               
                        }
    FILTER NOT EXISTS {    
        # ?entity rdfs:subClassOf ?restriction . 
        # ?restriction rdf:type owl:Restriction ; 
                owl:onProperty ?property  ; 
                owl:someValuesFrom ?data.}

}ORDER BY ?entity
    
    
"""

# %%
results = g.query(q)
print(f"nb formats missing is_format_of property: {len(results)} ")
df = pd.DataFrame(columns=["entity","label","property"])
for r in results:
        pd.set_option("display.max_rows",None,"display.max_colwidth",5000,"display.width",5000,)
        concept = pd.DataFrame([[r["entity"], r["label"], r["property"]]],columns=["entity","label","property"])
        df=pd.concat([df, concept], ignore_index=True)
df.index = np.arange(1, len(df) + 1)
display(df)
# Out:
# nb formats missing is_format_of property: 85
#                                  entity                                                                       label                              property
# 1   http://edamontology.org/format_1295                                                                 quicktandem  http://edamontology.org/is_format_of
# 2   http://edamontology.org/format_1296                                                     Sanger inverted repeats  http://edamontology.org/is_format_of
# 3   http://edamontology.org/format_1297                                                               EMBOSS repeat  http://edamontology.org/is_format_of
# 4   http://edamontology.org/format_1318                                                             restrict format  http://edamontology.org/is_format_of
# 5   http://edamontology.org/format_1319                                                             restover format  http://edamontology.org/is_format_of
# 6   http://edamontology.org/format_1320                                                    REBASE restriction sites  http://edamontology.org/is_format_of
# 7   http://edamontology.org/format_1454                                                                        dssp  http://edamontology.org/is_format_of
# 8   http://edamontology.org/format_1455                                                                        hssp  http://edamontology.org/is_format_of
# 9   http://edamontology.org/format_1627                                                              Primer3 primer  http://edamontology.org/is_format_of
# 10  http://edamontology.org/format_1665                                                     Taverna workflow format  http://edamontology.org/is_format_of
# 11  http://edamontology.org/format_1948                                                                    nbrf/pir  http://edamontology.org/is_format_of
# 12  http://edamontology.org/format_1964                                             plain text format (unformatted)  http://edamontology.org/is_format_of
# 13  http://edamontology.org/format_2032                                                             Workflow format  http://edamontology.org/is_format_of
# 14  http://edamontology.org/format_2033                                                   Tertiary structure format  http://edamontology.org/is_format_of
# 15  http://edamontology.org/format_2061                                      Nucleic acid features (primers) format  http://edamontology.org/is_format_of
# 16  http://edamontology.org/format_2077                                          Protein secondary structure format  http://edamontology.org/is_format_of
# 17  http://edamontology.org/format_2155                                          Sequence features (repeats) format  http://edamontology.org/is_format_of
# 18  http://edamontology.org/format_2158                            Nucleic acid features (restriction sites) format  http://edamontology.org/is_format_of
# 19  http://edamontology.org/format_2330                                                              Textual format  http://edamontology.org/is_format_of
# 20  http://edamontology.org/format_2332                                                                         XML  http://edamontology.org/is_format_of
# 21  http://edamontology.org/format_2333                                                               Binary format  http://edamontology.org/is_format_of
# 22  http://edamontology.org/format_2350                                                    Format (by type of data)  http://edamontology.org/is_format_of
# 23  http://edamontology.org/format_3285                                                                         MAP  http://edamontology.org/is_format_of
# 24  http://edamontology.org/format_3286                                                                         PED  http://edamontology.org/is_format_of
# 25  http://edamontology.org/format_3287                                              Individual genetic data format  http://edamontology.org/is_format_of
# 26  http://edamontology.org/format_3288                                                                     PED/MAP  http://edamontology.org/is_format_of
# 27  http://edamontology.org/format_3464                                                                        JSON  http://edamontology.org/is_format_of
# 28  http://edamontology.org/format_3466                                                                         EPS  http://edamontology.org/is_format_of
# 29  http://edamontology.org/format_3467                                                                         GIF  http://edamontology.org/is_format_of
# 30  http://edamontology.org/format_3468                                                                         xls  http://edamontology.org/is_format_of
# 31  http://edamontology.org/format_3475                                                                         TSV  http://edamontology.org/is_format_of
# 32  http://edamontology.org/format_3506                                                                        docx  http://edamontology.org/is_format_of
# 33  http://edamontology.org/format_3507                                                             Document format  http://edamontology.org/is_format_of
# 34  http://edamontology.org/format_3508                                                                         PDF  http://edamontology.org/is_format_of
# 35  http://edamontology.org/format_3554                                                               R file format  http://edamontology.org/is_format_of
# 36  http://edamontology.org/format_3555                                                                        SPSS  http://edamontology.org/is_format_of
# 37  http://edamontology.org/format_3581                                                                        arff  http://edamontology.org/is_format_of
# 38  http://edamontology.org/format_3617                                                                Graph format  http://edamontology.org/is_format_of
# 39  http://edamontology.org/format_3618                                                                       xgmml  http://edamontology.org/is_format_of
# 40  http://edamontology.org/format_3620                                                                        xlsx  http://edamontology.org/is_format_of
# 41  http://edamontology.org/format_3621                                                               SQLite format  http://edamontology.org/is_format_of
# 42  http://edamontology.org/format_3665                                                            K-mer countgraph  http://edamontology.org/is_format_of
# 43  http://edamontology.org/format_3690                                                                        BDML  http://edamontology.org/is_format_of
# 44  http://edamontology.org/format_3691                                                                         BEL  http://edamontology.org/is_format_of
# 45  http://edamontology.org/format_3696                                                                          PS  http://edamontology.org/is_format_of
# 46  http://edamontology.org/format_3698                                                                  SRA format  http://edamontology.org/is_format_of
# 47  http://edamontology.org/format_3699                                                                         VDB  http://edamontology.org/is_format_of
# 48  http://edamontology.org/format_3725                                                                        SBOL  http://edamontology.org/is_format_of
# 49  http://edamontology.org/format_3726                                                                        PMML  http://edamontology.org/is_format_of
# 50  http://edamontology.org/format_3728                                                                  LocARNA PP  http://edamontology.org/is_format_of
# 51  http://edamontology.org/format_3729                                                                dbGaP format  http://edamontology.org/is_format_of
# 52  http://edamontology.org/format_3748                                                          Linked data format  http://edamontology.org/is_format_of
# 53  http://edamontology.org/format_3750                                                                        YAML  http://edamontology.org/is_format_of
# 54  http://edamontology.org/format_3751                                                                         DSV  http://edamontology.org/is_format_of
# 55  http://edamontology.org/format_3752                                                                         CSV  http://edamontology.org/is_format_of
# 56  http://edamontology.org/format_3765                                                      KNIME datatable format  http://edamontology.org/is_format_of
# 57  http://edamontology.org/format_3788                                                                         SQL  http://edamontology.org/is_format_of
# 58  http://edamontology.org/format_3789                                                                      XQuery  http://edamontology.org/is_format_of
# 59  http://edamontology.org/format_3790                                                                      SPARQL  http://edamontology.org/is_format_of
# 60  http://edamontology.org/format_3804                                                                         xsd  http://edamontology.org/is_format_of
# 61  http://edamontology.org/format_3813                                                          SAMPLE file format  http://edamontology.org/is_format_of
# 62  http://edamontology.org/format_3817                                                                       latex  http://edamontology.org/is_format_of
# 63  http://edamontology.org/format_3841                                                                  NLP format  http://edamontology.org/is_format_of
# 64  http://edamontology.org/format_3857                                                                         CWL  http://edamontology.org/is_format_of
# 65  http://edamontology.org/format_3862                                                       NLP annotation format  http://edamontology.org/is_format_of
# 66  http://edamontology.org/format_3863                                                           NLP corpus format  http://edamontology.org/is_format_of
# 67  http://edamontology.org/format_3865                                                       RNA annotation format  http://edamontology.org/is_format_of
# 68  http://edamontology.org/format_3973                                                                Docker image  http://edamontology.org/is_format_of
# 69  http://edamontology.org/format_3977                                                                   ObjTables  http://edamontology.org/is_format_of
# 70  http://edamontology.org/format_3981                                                                  TAR format  http://edamontology.org/is_format_of
# 71  http://edamontology.org/format_3985                                                                   gxformat2  http://edamontology.org/is_format_of
# 72  http://edamontology.org/format_3987                                                                  ZIP format  http://edamontology.org/is_format_of
# 73  http://edamontology.org/format_3989                                                                 GZIP format  http://edamontology.org/is_format_of
# 74  http://edamontology.org/format_3996                                                               Python script  http://edamontology.org/is_format_of
# 75  http://edamontology.org/format_3998                                                                 Perl script  http://edamontology.org/is_format_of
# 76  http://edamontology.org/format_3999                                                                    R script  http://edamontology.org/is_format_of
# 77  http://edamontology.org/format_4000                                                                  R markdown  http://edamontology.org/is_format_of
# 78  http://edamontology.org/format_4002                                                                      pickle  http://edamontology.org/is_format_of
# 79  http://edamontology.org/format_4003                                                                NumPy format  http://edamontology.org/is_format_of
# 80  http://edamontology.org/format_4004                                             SimTools repertoire file format  http://edamontology.org/is_format_of
# 81  http://edamontology.org/format_4005                                                   Configuration file format  http://edamontology.org/is_format_of
# 82  http://edamontology.org/format_4006                                                            Zstandard format  http://edamontology.org/is_format_of
# 83  http://edamontology.org/format_4007                                                               MATLAB script  http://edamontology.org/is_format_of
# 84  http://edamontology.org/format_4025          BioSimulators format for the specifications of biosimulation tools  http://edamontology.org/is_format_of
# 85  http://edamontology.org/format_4026  BioSimulators standard for command-line interfaces for biosimulation tools  http://edamontology.org/is_format_of

# %% [markdown]
# ## query to see format with is_format_of property

# %%
q2= """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

SELECT DISTINCT ?entity ?label ?data
WHERE {
    # ?entity rdfs:subClassOf ?restriction . 
    # ?restriction rdf:type owl:Restriction ; 
            owl:onProperty edam:is_format_of  ; 
            owl:someValuesFrom ?data.
    # ?entity rdfs:label ?label .
    }
"""

# %%
results = g.query(q2)
print(f"nb formats with is_format_of property: {len(results)} ")
df = pd.DataFrame(columns=["entity","label","data"])
for r in results:
        pd.set_option("display.max_rows",None,"display.max_colwidth",5000,"display.width",5000,)
        concept = pd.DataFrame([[r["entity"], r["label"], r["data"]]],columns=["entity","label","data"])
        df=pd.concat([df, concept], ignore_index=True)
df.index = np.arange(1, len(df) + 1)
display(df)
# Out:
# nb formats with is_format_of property: 111
#                                   entity                                                  label                               data
# 1    http://edamontology.org/format_1475                              PDB database entry format  http://edamontology.org/data_0883
# 2    http://edamontology.org/format_1475                              PDB database entry format  http://edamontology.org/data_3870
# 3    http://edamontology.org/format_1637                                                    dat  http://edamontology.org/data_1714
# 4    http://edamontology.org/format_1638                                                    cel  http://edamontology.org/data_3110
# 5    http://edamontology.org/format_1644                                                    CHP  http://edamontology.org/data_3111
# 6    http://edamontology.org/format_1919                                 Sequence record format  http://edamontology.org/data_0849
# 7    http://edamontology.org/format_1920                     Sequence feature annotation format  http://edamontology.org/data_1255
# 8    http://edamontology.org/format_1921                                       Alignment format  http://edamontology.org/data_0863
# 9    http://edamontology.org/format_2006                               Phylogenetic tree format  http://edamontology.org/data_0872
# 10   http://edamontology.org/format_2013                   Biological pathway or network format  http://edamontology.org/data_2600
# 11   http://edamontology.org/format_2014                      Sequence-profile alignment format  http://edamontology.org/data_0858
# 12   http://edamontology.org/format_2017                                Amino acid index format  http://edamontology.org/data_1501
# 13   http://edamontology.org/format_2020                                         Article format  http://edamontology.org/data_0971
# 14   http://edamontology.org/format_2021                              Text mining report format  http://edamontology.org/data_0972
# 15   http://edamontology.org/format_2027                          Enzyme kinetics report format  http://edamontology.org/data_2024
# 16   http://edamontology.org/format_2030                                   Chemical data format  http://edamontology.org/data_0962
# 17   http://edamontology.org/format_2031                                 Gene annotation format  http://edamontology.org/data_0916
# 18   http://edamontology.org/format_2035                                Chemical formula format  http://edamontology.org/data_0846
# 19   http://edamontology.org/format_2036                     Phylogenetic character data format  http://edamontology.org/data_0871
# 20   http://edamontology.org/format_2037  Phylogenetic continuous quantitative character format  http://edamontology.org/data_1426
# 21   http://edamontology.org/format_2038                    Phylogenetic discrete states format  http://edamontology.org/data_1427
# 22   http://edamontology.org/format_2039              Phylogenetic tree report (cliques) format  http://edamontology.org/data_1428
# 23   http://edamontology.org/format_2040           Phylogenetic tree report (invariants) format  http://edamontology.org/data_1429
# 24   http://edamontology.org/format_2049       Phylogenetic tree report (tree distances) format  http://edamontology.org/data_1442
# 25   http://edamontology.org/format_2052                           Protein family report format  http://edamontology.org/data_0907
# 26   http://edamontology.org/format_2054                             Protein interaction format  http://edamontology.org/data_0906
# 27   http://edamontology.org/format_2055                               Sequence assembly format  http://edamontology.org/data_0925
# 28   http://edamontology.org/format_2057                                  Sequence trace format  http://edamontology.org/data_0924
# 29   http://edamontology.org/format_2058                          Gene expression report format  http://edamontology.org/data_2603
# 30   http://edamontology.org/format_2060                                             Map format  http://edamontology.org/data_1274
# 31   http://edamontology.org/format_2062                                  Protein report format  http://edamontology.org/data_0896
# 32   http://edamontology.org/format_2064                            3D-1D scoring matrix format  http://edamontology.org/data_1499
# 33   http://edamontology.org/format_2065   Protein structure report (quality evaluation) format  http://edamontology.org/data_1539
# 34   http://edamontology.org/format_2066                        Database hits (sequence) format  http://edamontology.org/data_0857
# 35   http://edamontology.org/format_2067                        Sequence distance matrix format  http://edamontology.org/data_0870
# 36   http://edamontology.org/format_2068                                  Sequence motif format  http://edamontology.org/data_1353
# 37   http://edamontology.org/format_2069                                Sequence profile format  http://edamontology.org/data_1354
# 38   http://edamontology.org/format_2072                             Hidden Markov model format  http://edamontology.org/data_1364
# 39   http://edamontology.org/format_2074                          Dirichlet distribution format  http://edamontology.org/data_1347
# 40   http://edamontology.org/format_2075              HMM emission and transition counts format  http://edamontology.org/data_3354
# 41   http://edamontology.org/format_2075              HMM emission and transition counts format  http://edamontology.org/data_3355
# 42   http://edamontology.org/format_2076                         RNA secondary structure format  http://edamontology.org/data_0880
# 43   http://edamontology.org/format_2078                                  Sequence range format  http://edamontology.org/data_1017
# 44   http://edamontology.org/format_2170                                Sequence cluster format  http://edamontology.org/data_1235
# 45   http://edamontology.org/format_2195                                        Ontology format  http://edamontology.org/data_0582
# 46   http://edamontology.org/format_2331                                                   HTML  http://edamontology.org/data_2048
# 47   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_0863
# 48   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_1255
# 49   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_1772
# 50   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_2044
# 51   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_3108
# 52   http://edamontology.org/format_2548                          Sequence feature table format  http://edamontology.org/data_1255
# 53   http://edamontology.org/format_2571                                    Raw sequence format  http://edamontology.org/data_2044
# 54   http://edamontology.org/format_2848                         Bibliographic reference format  http://edamontology.org/data_0970
# 55   http://edamontology.org/format_2848                         Bibliographic reference format  http://edamontology.org/data_2849
# 56   http://edamontology.org/format_2919                       Sequence annotation track format  http://edamontology.org/data_3002
# 57   http://edamontology.org/format_2920                           Alignment format (pair only)  http://edamontology.org/data_1381
# 58   http://edamontology.org/format_2921                   Sequence variation annotation format  http://edamontology.org/data_3498
# 59   http://edamontology.org/format_3033                                          Matrix format  http://edamontology.org/data_2082
# 60   http://edamontology.org/format_3097                   Protein domain classification format  http://edamontology.org/data_0907
# 61   http://edamontology.org/format_3161                                                MAGE-ML  http://edamontology.org/data_3111
# 62   http://edamontology.org/format_3162                                               MAGE-TAB  http://edamontology.org/data_3111
# 63   http://edamontology.org/format_3166            Biological pathway or network report format  http://edamontology.org/data_2984
# 64   http://edamontology.org/format_3167                           Experiment annotation format  http://edamontology.org/data_2531
# 65   http://edamontology.org/format_3235                                        Cytoband format  http://edamontology.org/data_3236
# 66   http://edamontology.org/format_3245                          Mass spectrometry data format  http://edamontology.org/data_2536
# 67   http://edamontology.org/format_3326                                      Data index format  http://edamontology.org/data_0955
# 68   http://edamontology.org/format_3327                                                    BAI  http://edamontology.org/data_0955
# 69   http://edamontology.org/format_3484                                                   ebwt  http://edamontology.org/data_3210
# 70   http://edamontology.org/format_3491                                                  ebwtl  http://edamontology.org/data_3210
# 71   http://edamontology.org/format_3547                                           Image format  http://edamontology.org/data_2968
# 72   http://edamontology.org/format_3578                                                   IDAT  http://edamontology.org/data_3110
# 73   http://edamontology.org/format_3606                  Sequence quality report format (text)  http://edamontology.org/data_2048
# 74   http://edamontology.org/format_3626                                                    MAT  http://edamontology.org/data_1499
# 75   http://edamontology.org/format_3700                                Tabix index file format  http://edamontology.org/data_0955
# 76   http://edamontology.org/format_3706                               Biodiversity data format  http://edamontology.org/data_3707
# 77   http://edamontology.org/format_3708                                            ABCD format  http://edamontology.org/data_3707
# 78   http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_0863
# 79   http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_1255
# 80   http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_1772
# 81   http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_2044
# 82   http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_3108
# 83   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_0863
# 84   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_1255
# 85   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_1772
# 86   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_2044
# 87   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_3108
# 88   http://edamontology.org/format_3774                                      BioJSON (Jalview)  http://edamontology.org/data_0863
# 89   http://edamontology.org/format_3774                                      BioJSON (Jalview)  http://edamontology.org/data_1255
# 90   http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_2530
# 91   http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_3113
# 92   http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_3567
# 93   http://edamontology.org/format_3780                                  Annotated text format  http://edamontology.org/data_3779
# 94   http://edamontology.org/format_3787                                         Query language  http://edamontology.org/data_3786
# 95   http://edamontology.org/format_3824                                        NMR data format  http://edamontology.org/data_3488
# 96   http://edamontology.org/format_3828                             Raw microarray data format  http://edamontology.org/data_3110
# 97   http://edamontology.org/format_3866                                      Trajectory format  http://edamontology.org/data_3870
# 98   http://edamontology.org/format_3879                                        Topology format  http://edamontology.org/data_3872
# 99   http://edamontology.org/format_3884                                    FF parameter format  http://edamontology.org/data_3872
# 100  http://edamontology.org/format_3909                                                BpForms  http://edamontology.org/data_1255
# 101  http://edamontology.org/format_3911                                                    msh  http://edamontology.org/data_2190
# 102  http://edamontology.org/format_3913                                                   Loom  http://edamontology.org/data_2535
# 103  http://edamontology.org/format_3913                                                   Loom  http://edamontology.org/data_3112
# 104  http://edamontology.org/format_3915                                                   Zarr  http://edamontology.org/data_2535
# 105  http://edamontology.org/format_3915                                                   Zarr  http://edamontology.org/data_3112
# 106  http://edamontology.org/format_3916                                                    MTX  http://edamontology.org/data_2535
# 107  http://edamontology.org/format_3916                                                    MTX  http://edamontology.org/data_3112
# 108  http://edamontology.org/format_3971                                                NeuroML  http://edamontology.org/data_3241
# 109  http://edamontology.org/format_3972                                                   BNGL  http://edamontology.org/data_3241
# 110  http://edamontology.org/format_4015                                                  PEtab  http://edamontology.org/data_3869
# 111  http://edamontology.org/format_4024                                                    cif  http://edamontology.org/data_0883

# %% [markdown]
# ## Create new triples to create all is_format_of relation possible

# %%
q3 = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

CONSTRUCT { 
    # ?children_format rdfs:subClassOf ?restriction . 
    # ?restriction rdf:type owl:Restriction ; 
            owl:onProperty edam:is_format_of  ; 
            owl:someValuesFrom ?data. 
}
WHERE {
    # ?parent_format rdfs:subClassOf ?restriction . 
    # ?restriction rdf:type owl:Restriction ; 
            owl:onProperty edam:is_format_of  ; 
            owl:someValuesFrom ?data.
    # ?children_format rdfs:subClassOf+ ?parent_format .
    }
    
    
"""

# %%
results = g.query(q3)
print(f"nb constructed is_format_of property: {len(results)} ")
df = pd.DataFrame(columns=["entity","property","object"])
for r in results:
        pd.set_option("display.max_rows",None,"display.max_colwidth",5000,"display.width",5000,)
        concept = pd.DataFrame([[r[0],r[1],r[2]]],columns=["entity","property","object"])
        df=pd.concat([df, concept], ignore_index=True)
        g.add((r[0],r[1],r[2]))
df.index = np.arange(1, len(df) + 1)
display(df)
# Out:
# nb constructed is_format_of property: 844
#                                   entity                                         property                                     object
# 1    http://edamontology.org/format_1739  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nccaafc7218ac4c5888c5c2a2062975ea
# 2    http://edamontology.org/format_1430  http://www.w3.org/2000/01/rdf-schema#subClassOf          N72002b38e4bd432aa779b309338f63f8
# 3    http://edamontology.org/format_3592  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 4    http://edamontology.org/format_1434  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6758ed77fffc42aaa23e8811007f9a30
# 5      Nccaafc7218ac4c5888c5c2a2062975ea  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 6    http://edamontology.org/format_1961  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 7      N4b9191880a7a475db2dce2b9120a1a7b         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 8    http://edamontology.org/format_3826  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 9      N75a240cf6b9943ea86a081ad9edc3901         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 10   http://edamontology.org/format_3820  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 11     Nd2f96ef2e76a48fc8932a235d2658dc1     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1381
# 12   http://edamontology.org/format_3913  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 13   http://edamontology.org/format_3651  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 14     Nfa2c11aaa1d248c3aafc1eecf3f05fe3         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 15   http://edamontology.org/format_1391  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 16   http://edamontology.org/format_3008  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 17   http://edamontology.org/format_3839  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 18     Nab9e82ab4fdf4065ad1d8e65c132844b         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 19   http://edamontology.org/format_1736  http://www.w3.org/2000/01/rdf-schema#subClassOf          N61fd37d6c1344bcb86559221a584b970
# 20   http://edamontology.org/format_3611  http://www.w3.org/2000/01/rdf-schema#subClassOf          N19fa0d641eba4d02bc63bea1baaf0857
# 21     Nf3e68b958c7d49ca877013c287515699  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 22   http://edamontology.org/format_3770  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 23     N3d5a9eff091b42b5a7e565c4b0f5555c         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 24   http://edamontology.org/format_3612  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 25   http://edamontology.org/format_3990  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 26   http://edamontology.org/format_3877  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 27   http://edamontology.org/format_3242  http://www.w3.org/2000/01/rdf-schema#subClassOf          N10b7a5667ef24b37ba4e494af2cafb6e
# 28   http://edamontology.org/format_1737  http://www.w3.org/2000/01/rdf-schema#subClassOf          N61fd37d6c1344bcb86559221a584b970
# 29   http://edamontology.org/format_2000  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 30   http://edamontology.org/format_1992  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 31     Nceafb4930b034fba96b9546702b5265d     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_3110
# 32   http://edamontology.org/format_3608  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 33   http://edamontology.org/format_3980  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 34   http://edamontology.org/format_1334  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 35   http://edamontology.org/format_1209  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 36   http://edamontology.org/format_2573  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 37   http://edamontology.org/format_1927  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 38   http://edamontology.org/format_1973  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 39     Ne91d4d6c066947f7ae73ea6120fba180         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 40   http://edamontology.org/format_1350  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9199956f593f4481833c19a91355cee2
# 41     N42f73de8478a49adb2da40fc46c86f4a         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 42   http://edamontology.org/format_3019  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 43   http://edamontology.org/format_3098  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd7297f2dcf844693bd407574760294a6
# 44   http://edamontology.org/format_3776  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 45   http://edamontology.org/format_3159  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 46   http://edamontology.org/format_1951  http://www.w3.org/2000/01/rdf-schema#subClassOf          N4b9191880a7a475db2dce2b9120a1a7b
# 47   http://edamontology.org/format_1349  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9199956f593f4481833c19a91355cee2
# 48   http://edamontology.org/format_1432  http://www.w3.org/2000/01/rdf-schema#subClassOf          N72002b38e4bd432aa779b309338f63f8
# 49     N19fa0d641eba4d02bc63bea1baaf0857  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 50   http://edamontology.org/format_3583  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 51   http://edamontology.org/format_3686  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d5a9eff091b42b5a7e565c4b0f5555c
# 52   http://edamontology.org/format_1424  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 53   http://edamontology.org/format_3845  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 54   http://edamontology.org/format_3655  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 55   http://edamontology.org/format_1953  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 56   http://edamontology.org/format_1963  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 57   http://edamontology.org/format_1219  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 58   http://edamontology.org/format_1629  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 59   http://edamontology.org/format_3247  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 60   http://edamontology.org/format_3596  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 61   http://edamontology.org/format_1951  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 62     Na3fa05840d66414b8d51199520183ea7         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 63   http://edamontology.org/format_1949  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 64   http://edamontology.org/format_3911  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 65   http://edamontology.org/format_3598  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 66     N4b9191880a7a475db2dce2b9120a1a7b     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0883
# 67   http://edamontology.org/format_1937  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 68   http://edamontology.org/format_3848  http://www.w3.org/2000/01/rdf-schema#subClassOf          N61fd37d6c1344bcb86559221a584b970
# 69   http://edamontology.org/format_2197  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 70   http://edamontology.org/format_3626  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nbf317b198ffa4cae8cc82e0c24607a7d
# 71   http://edamontology.org/format_1986  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 72   http://edamontology.org/format_3157  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 73   http://edamontology.org/format_1437  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 74   http://edamontology.org/format_3550  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 75   http://edamontology.org/format_1628  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 76   http://edamontology.org/format_3256  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 77   http://edamontology.org/format_3878  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 78   http://edamontology.org/format_3609  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 79   http://edamontology.org/format_1422  http://www.w3.org/2000/01/rdf-schema#subClassOf          N15050aa2086540ea902493e24c61ca31
# 80   http://edamontology.org/format_3880  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nadff97c82cf8418fbdb0bd146ca96813
# 81   http://edamontology.org/format_1998  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 82     Nae710a1ac1b1447ab0325c139674e1c1     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0863
# 83   http://edamontology.org/format_3650  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 84   http://edamontology.org/format_3261  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 85   http://edamontology.org/format_2194  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nccaafc7218ac4c5888c5c2a2062975ea
# 86   http://edamontology.org/format_1975  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 87   http://edamontology.org/format_2064  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nbf317b198ffa4cae8cc82e0c24607a7d
# 88   http://edamontology.org/format_1217  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 89   http://edamontology.org/format_3888  http://www.w3.org/2000/01/rdf-schema#subClassOf          Naa3b59169a334e6285611e06ed791f4a
# 90   http://edamontology.org/format_3773  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 91   http://edamontology.org/format_1985  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 92   http://edamontology.org/format_3814  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ne91d4d6c066947f7ae73ea6120fba180
# 93   http://edamontology.org/format_3822  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 94   http://edamontology.org/format_2037  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 95   http://edamontology.org/format_3836  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 96   http://edamontology.org/format_3485  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 97   http://edamontology.org/format_3876  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 98   http://edamontology.org/format_3157  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd2f96ef2e76a48fc8932a235d2658dc1
# 99   http://edamontology.org/format_1637  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 100  http://edamontology.org/format_3685  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d5a9eff091b42b5a7e565c4b0f5555c
# 101  http://edamontology.org/format_3613  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 102    N75a240cf6b9943ea86a081ad9edc3901  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 103  http://edamontology.org/format_2352  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 104  http://edamontology.org/format_3587  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 105  http://edamontology.org/format_3330  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 106  http://edamontology.org/format_3709  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 107  http://edamontology.org/format_2310  http://www.w3.org/2000/01/rdf-schema#subClassOf          N368fe0842d9147e792f2b89c9fadd4a1
# 108  http://edamontology.org/format_1740  http://www.w3.org/2000/01/rdf-schema#subClassOf          N368fe0842d9147e792f2b89c9fadd4a1
# 109    Nd1905e412f5041d3b714f52c72866047         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 110  http://edamontology.org/format_3816  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ne91d4d6c066947f7ae73ea6120fba180
# 111  http://edamontology.org/format_1477  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 112  http://edamontology.org/format_2923  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 113    N3d8a8879c100415fb46ec3c6edc4dbd5         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 114  http://edamontology.org/format_4035  http://www.w3.org/2000/01/rdf-schema#subClassOf          N4b9191880a7a475db2dce2b9120a1a7b
# 115    Nab9e82ab4fdf4065ad1d8e65c132844b  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 116  http://edamontology.org/format_2172  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndb79d885c863409597ee4c5977d667f6
# 117  http://edamontology.org/format_1367  http://www.w3.org/2000/01/rdf-schema#subClassOf          N948b083d02864b97809e370676dd06c4
# 118  http://edamontology.org/format_2924  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 119  http://edamontology.org/format_3692  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 120    N3d5a9eff091b42b5a7e565c4b0f5555c  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 121  http://edamontology.org/format_3883  http://www.w3.org/2000/01/rdf-schema#subClassOf          Naa3b59169a334e6285611e06ed791f4a
# 122  http://edamontology.org/format_3686  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 123    N1a9f30f519b849b2aa1fe9ed99af3dad         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 124  http://edamontology.org/format_3851  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 125  http://edamontology.org/format_3486  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 126  http://edamontology.org/format_2095  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 127  http://edamontology.org/format_2573  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 128  http://edamontology.org/format_3013  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 129    N1c68632337284886b39419bdb2d6447a     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2603
# 130  http://edamontology.org/format_2038  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 131    Neac21c0661cd40f28af81702bb52d7bd     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1274
# 132  http://edamontology.org/format_2094  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 133  http://edamontology.org/format_3775  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 134  http://edamontology.org/format_3239  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 135  http://edamontology.org/format_3329  http://www.w3.org/2000/01/rdf-schema#subClassOf          N948b083d02864b97809e370676dd06c4
# 136  http://edamontology.org/format_1945  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 137  http://edamontology.org/format_3604  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 138  http://edamontology.org/format_3158  http://www.w3.org/2000/01/rdf-schema#subClassOf          N10b7a5667ef24b37ba4e494af2cafb6e
# 139    N9199956f593f4481833c19a91355cee2     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1347
# 140  http://edamontology.org/format_3011  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 141  http://edamontology.org/format_1639  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndb79d885c863409597ee4c5977d667f6
# 142    Nfa2c11aaa1d248c3aafc1eecf3f05fe3     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2984
# 143  http://edamontology.org/format_1982  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 144    N519e070397734f15b7720a53f5d35b1a         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 145  http://edamontology.org/format_1248  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd7864e40937c4e2f9c2d5348d376d91a
# 146  http://edamontology.org/format_1944  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 147  http://edamontology.org/format_3827  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 148  http://edamontology.org/format_1336  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 149  http://edamontology.org/format_3013  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd2f96ef2e76a48fc8932a235d2658dc1
# 150  http://edamontology.org/format_2559  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 151  http://edamontology.org/format_4036  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 152  http://edamontology.org/format_3003  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 153    N3f0a1accea8e4b859396ba2edf2ed737     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_3498
# 154    Nfa2c11aaa1d248c3aafc1eecf3f05fe3  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 155  http://edamontology.org/format_2181  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 156  http://edamontology.org/format_3820  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 157  http://edamontology.org/format_2547  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 158  http://edamontology.org/format_1342  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 159  http://edamontology.org/format_1433  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nf3e68b958c7d49ca877013c287515699
# 160  http://edamontology.org/format_1369  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc0dc52b4cbed4515bb1f83b4df84a4a3
# 161  http://edamontology.org/format_3885  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 162    Na3fa05840d66414b8d51199520183ea7  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 163  http://edamontology.org/format_1628  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 164  http://edamontology.org/format_1740  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1a9f30f519b849b2aa1fe9ed99af3dad
# 165  http://edamontology.org/format_3693  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndddd34a33f3949148b10d924aeb241e1
# 166  http://edamontology.org/format_3610  http://www.w3.org/2000/01/rdf-schema#subClassOf          N19fa0d641eba4d02bc63bea1baaf0857
# 167  http://edamontology.org/format_1214  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 168  http://edamontology.org/format_1925  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 169  http://edamontology.org/format_3969  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 170  http://edamontology.org/format_3710  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 171  http://edamontology.org/format_3012  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 172  http://edamontology.org/format_3619  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 173  http://edamontology.org/format_3909  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 174  http://edamontology.org/format_1947  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 175    N0c1dd7ec218945978ef0744a781885cc  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 176  http://edamontology.org/format_2570  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 177  http://edamontology.org/format_1978  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 178  http://edamontology.org/format_1935  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 179    Na3fa05840d66414b8d51199520183ea7     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0871
# 180  http://edamontology.org/format_3979  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndd79e61007b349d991b0d43e33f05e59
# 181  http://edamontology.org/format_3487  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 182    Nccaafc7218ac4c5888c5c2a2062975ea     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0971
# 183    Nc2db35983c5140d08b979b58ad9732d8  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 184  http://edamontology.org/format_3600  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 185  http://edamontology.org/format_4023  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ne91d4d6c066947f7ae73ea6120fba180
# 186    N6758ed77fffc42aaa23e8811007f9a30     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1428
# 187    N3d5a9eff091b42b5a7e565c4b0f5555c     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2531
# 188    Ne91d4d6c066947f7ae73ea6120fba180  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 189  http://edamontology.org/format_1208  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 190  http://edamontology.org/format_3978  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 191    N8806f5db692c487da115ab105d9eaec4         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 192  http://edamontology.org/format_3622  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3f0a1accea8e4b859396ba2edf2ed737
# 193  http://edamontology.org/format_3886  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 194    Nd1905e412f5041d3b714f52c72866047  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 195  http://edamontology.org/format_3310  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nf0320cf8b2354dea961c704557704e55
# 196  http://edamontology.org/format_3549  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 197  http://edamontology.org/format_1983  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 198  http://edamontology.org/format_3838  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 199  http://edamontology.org/format_1632  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 200  http://edamontology.org/format_1215  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 201  http://edamontology.org/format_1341  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 202  http://edamontology.org/format_3991  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 203  http://edamontology.org/format_3972  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 204    Nbf317b198ffa4cae8cc82e0c24607a7d  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 205  http://edamontology.org/format_2040  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 206  http://edamontology.org/format_3608  http://www.w3.org/2000/01/rdf-schema#subClassOf          N19fa0d641eba4d02bc63bea1baaf0857
# 207  http://edamontology.org/format_1968  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 208  http://edamontology.org/format_3773  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 209  http://edamontology.org/format_2376  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 210    N9199956f593f4481833c19a91355cee2  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 211  http://edamontology.org/format_1943  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 212  http://edamontology.org/format_1343  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 213  http://edamontology.org/format_1333  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 214  http://edamontology.org/format_3594  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 215  http://edamontology.org/format_3605  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 216  http://edamontology.org/format_3889  http://www.w3.org/2000/01/rdf-schema#subClassOf          Naa3b59169a334e6285611e06ed791f4a
# 217  http://edamontology.org/format_2553  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 218  http://edamontology.org/format_3164  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 219    N454c11ef5b044f70a6528e606501b75c         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 220  http://edamontology.org/format_2352  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 221  http://edamontology.org/format_1974  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 222  http://edamontology.org/format_3819  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 223  http://edamontology.org/format_1997  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 224  http://edamontology.org/format_1430  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 225  http://edamontology.org/format_2184  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 226  http://edamontology.org/format_3615  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 227  http://edamontology.org/format_3883  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nadff97c82cf8418fbdb0bd146ca96813
# 228  http://edamontology.org/format_3770  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 229  http://edamontology.org/format_3281  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 230  http://edamontology.org/format_3583  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 231  http://edamontology.org/format_2545  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 232  http://edamontology.org/format_3868  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 233  http://edamontology.org/format_3591  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 234  http://edamontology.org/format_3018  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 235  http://edamontology.org/format_1366  http://www.w3.org/2000/01/rdf-schema#subClassOf          N948b083d02864b97809e370676dd06c4
# 236  http://edamontology.org/format_3312  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 237    N3447fcc421a340ff9e376e3f6e0cbf1b     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2849
# 238  http://edamontology.org/format_3956  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 239  http://edamontology.org/format_1912  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 240  http://edamontology.org/format_1927  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 241  http://edamontology.org/format_3609  http://www.w3.org/2000/01/rdf-schema#subClassOf          N19fa0d641eba4d02bc63bea1baaf0857
# 242  http://edamontology.org/format_1910  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 243  http://edamontology.org/format_3652  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 244  http://edamontology.org/format_3772  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 245  http://edamontology.org/format_3771  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 246  http://edamontology.org/format_1938  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 247    N1c68632337284886b39419bdb2d6447a         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 248  http://edamontology.org/format_2567  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 249    Naa3b59169a334e6285611e06ed791f4a     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_3872
# 250  http://edamontology.org/format_3843  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 251    Nd7297f2dcf844693bd407574760294a6         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 252  http://edamontology.org/format_3603  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 253  http://edamontology.org/format_1951  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 254    N9bc78ee2de4d45d08e7bf0b5ca4a1f8d         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 255  http://edamontology.org/format_3582  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndddd34a33f3949148b10d924aeb241e1
# 256    Nf0320cf8b2354dea961c704557704e55     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0880
# 257    N7a14904457444ca5b7bfd694a46ec123         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 258    N1a9f30f519b849b2aa1fe9ed99af3dad  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 259  http://edamontology.org/format_3771  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 260    N6a94bccb14ab4e4a90f2257e822abf77         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 261    N2ba7689427f74a62b7718a84052149ef         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 262    N8806f5db692c487da115ab105d9eaec4  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 263    N61fd37d6c1344bcb86559221a584b970         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 264  http://edamontology.org/format_3020  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3f0a1accea8e4b859396ba2edf2ed737
# 265  http://edamontology.org/format_3815  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ne91d4d6c066947f7ae73ea6120fba180
# 266  http://edamontology.org/format_1432  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 267  http://edamontology.org/format_3749  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 268  http://edamontology.org/format_3864  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 269    N6a94bccb14ab4e4a90f2257e822abf77     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2968
# 270  http://edamontology.org/format_1950  http://www.w3.org/2000/01/rdf-schema#subClassOf          N4b9191880a7a475db2dce2b9120a1a7b
# 271  http://edamontology.org/format_3821  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 272  http://edamontology.org/format_1962  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 273  http://edamontology.org/format_3311  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 274  http://edamontology.org/format_1991  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 275  http://edamontology.org/format_1950  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 276  http://edamontology.org/format_2187  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 277    N42f73de8478a49adb2da40fc46c86f4a     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0872
# 278  http://edamontology.org/format_3597  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 279    Nae710a1ac1b1447ab0325c139674e1c1         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 280  http://edamontology.org/format_3758  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 281  http://edamontology.org/format_1476  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1e5c10f31da4b99b437c8670f275a1b
# 282  http://edamontology.org/format_1436  http://www.w3.org/2000/01/rdf-schema#subClassOf          N42f73de8478a49adb2da40fc46c86f4a
# 283  http://edamontology.org/format_3235  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd7864e40937c4e2f9c2d5348d376d91a
# 284  http://edamontology.org/format_3556  http://www.w3.org/2000/01/rdf-schema#subClassOf          N368fe0842d9147e792f2b89c9fadd4a1
# 285  http://edamontology.org/format_1316  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndd79e61007b349d991b0d43e33f05e59
# 286    N454c11ef5b044f70a6528e606501b75c  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 287    Nd1f6d47a6c284630b1f2490ddf0b6970         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 288  http://edamontology.org/format_3701  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 289  http://edamontology.org/format_1735  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3447fcc421a340ff9e376e3f6e0cbf1b
# 290    N10b7a5667ef24b37ba4e494af2cafb6e         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 291    N3447fcc421a340ff9e376e3f6e0cbf1b  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 292  http://edamontology.org/format_1423  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1905e412f5041d3b714f52c72866047
# 293  http://edamontology.org/format_2545  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 294  http://edamontology.org/format_3018  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 295  http://edamontology.org/format_3747  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 296  http://edamontology.org/format_2183  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 297  http://edamontology.org/format_3624  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd4c93ae1aa8d45d6b077d5bb618537ac
# 298    Nc9e2b1f7e87649928e37111d8ae441b1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 299  http://edamontology.org/format_3689  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 300  http://edamontology.org/format_2310  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 301  http://edamontology.org/format_3777  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nca798d22222e4c44b05f249edb9ad5a9
# 302    Nca798d22222e4c44b05f249edb9ad5a9         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 303  http://edamontology.org/format_3593  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 304  http://edamontology.org/format_1990  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 305  http://edamontology.org/format_3850  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndd79e61007b349d991b0d43e33f05e59
# 306  http://edamontology.org/format_3975  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndddd34a33f3949148b10d924aeb241e1
# 307  http://edamontology.org/format_3764  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 308  http://edamontology.org/format_1953  http://www.w3.org/2000/01/rdf-schema#subClassOf          N4b9191880a7a475db2dce2b9120a1a7b
# 309  http://edamontology.org/format_3016  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3f0a1accea8e4b859396ba2edf2ed737
# 310  http://edamontology.org/format_3915  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 311    N3a4175c1465a43e6b6743de13fa7d1d6  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 312    Nca798d22222e4c44b05f249edb9ad5a9     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_3707
# 313    Nceafb4930b034fba96b9546702b5265d  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 314    Nab9e82ab4fdf4065ad1d8e65c132844b     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0582
# 315  http://edamontology.org/format_3688  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 316  http://edamontology.org/format_1337  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 317    N9bc78ee2de4d45d08e7bf0b5ca4a1f8d  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 318  http://edamontology.org/format_3683  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 319  http://edamontology.org/format_3284  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 320  http://edamontology.org/format_2206  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 321    Neac21c0661cd40f28af81702bb52d7bd  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 322    Nd1905e412f5041d3b714f52c72866047     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0870
# 323    Nadb5459110ec4dff87b7968b1072df2f         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 324  http://edamontology.org/format_3313  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 325  http://edamontology.org/format_3243  http://www.w3.org/2000/01/rdf-schema#subClassOf          N10b7a5667ef24b37ba4e494af2cafb6e
# 326  http://edamontology.org/format_3874  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 327  http://edamontology.org/format_3811  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 328    N2ba7689427f74a62b7718a84052149ef  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 329    Nd7864e40937c4e2f9c2d5348d376d91a     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1017
# 330    N9bc78ee2de4d45d08e7bf0b5ca4a1f8d     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2044
# 331  http://edamontology.org/format_3992  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd2f96ef2e76a48fc8932a235d2658dc1
# 332  http://edamontology.org/format_3015  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 333  http://edamontology.org/format_1734  http://www.w3.org/2000/01/rdf-schema#subClassOf          N61fd37d6c1344bcb86559221a584b970
# 334  http://edamontology.org/format_2004  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 335  http://edamontology.org/format_2550  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 336  http://edamontology.org/format_2922  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 337  http://edamontology.org/format_3881  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nadff97c82cf8418fbdb0bd146ca96813
# 338  http://edamontology.org/format_3252  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 339  http://edamontology.org/format_1206  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 340  http://edamontology.org/format_1741  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nfcaab861353744fd9d5af10bec0b8b15
# 341  http://edamontology.org/format_1445  http://www.w3.org/2000/01/rdf-schema#subClassOf          N255b458cf65342d9a497ddddd5912770
# 342    N6d3d10d4b7f94b6ea3698380712986e1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 343  http://edamontology.org/format_2551  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 344    N15050aa2086540ea902493e24c61ca31     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0858
# 345  http://edamontology.org/format_1631  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndddd34a33f3949148b10d924aeb241e1
# 346  http://edamontology.org/format_3255  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 347  http://edamontology.org/format_3599  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 348  http://edamontology.org/format_3993  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 349  http://edamontology.org/format_3991  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 350  http://edamontology.org/format_1477  http://www.w3.org/2000/01/rdf-schema#subClassOf          N4b9191880a7a475db2dce2b9120a1a7b
# 351  http://edamontology.org/format_3708  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nca798d22222e4c44b05f249edb9ad5a9
# 352  http://edamontology.org/format_2005  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 353    N0e6c1f7eecbe4796b6b8d12a5038f649         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 354  http://edamontology.org/format_3783  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nfcaab861353744fd9d5af10bec0b8b15
# 355  http://edamontology.org/format_3882  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nadff97c82cf8418fbdb0bd146ca96813
# 356  http://edamontology.org/format_3015  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd2f96ef2e76a48fc8932a235d2658dc1
# 357  http://edamontology.org/format_1929  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 358  http://edamontology.org/format_2204  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 359  http://edamontology.org/format_3586  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# ...
# 725    Nd2f96ef2e76a48fc8932a235d2658dc1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 726  http://edamontology.org/format_3811  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 727  http://edamontology.org/format_2017  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nbf317b198ffa4cae8cc82e0c24607a7d
# 728  http://edamontology.org/format_3584  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 729  http://edamontology.org/format_1940  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 730  http://edamontology.org/format_1988  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 731    Nadb5459110ec4dff87b7968b1072df2f  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 732    Nc9e2b1f7e87649928e37111d8ae441b1         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 733  http://edamontology.org/format_3246  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 734  http://edamontology.org/format_1370  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc0dc52b4cbed4515bb1f83b4df84a4a3
# 735  http://edamontology.org/format_3773  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 736    N6d3d10d4b7f94b6ea3698380712986e1         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 737  http://edamontology.org/format_2572  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 738  http://edamontology.org/format_2187  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 739  http://edamontology.org/format_1931  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 740  http://edamontology.org/format_3008  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 741  http://edamontology.org/format_2182  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 742  http://edamontology.org/format_2311  http://www.w3.org/2000/01/rdf-schema#subClassOf          N368fe0842d9147e792f2b89c9fadd4a1
# 743  http://edamontology.org/format_3254  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nab9e82ab4fdf4065ad1d8e65c132844b
# 744    Nd4c93ae1aa8d45d6b077d5bb618537ac     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_0955
# 745  http://edamontology.org/format_3614  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 746  http://edamontology.org/format_1928  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 747  http://edamontology.org/format_3830  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 748  http://edamontology.org/format_3994  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 749  http://edamontology.org/format_2005  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 750  http://edamontology.org/format_2352  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 751  http://edamontology.org/format_3712  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 752    N3a4175c1465a43e6b6743de13fa7d1d6         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 753  http://edamontology.org/format_3610  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 754  http://edamontology.org/format_1972  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 755    Nceafb4930b034fba96b9546702b5265d         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 756  http://edamontology.org/format_1929  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 757  http://edamontology.org/format_3162  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 758  http://edamontology.org/format_3701  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 759  http://edamontology.org/format_1934  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 760  http://edamontology.org/format_1457  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nf0320cf8b2354dea961c704557704e55
# 761  http://edamontology.org/format_3916  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 762    N0e6c1f7eecbe4796b6b8d12a5038f649  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 763    Nfcaab861353744fd9d5af10bec0b8b15     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_3779
# 764  http://edamontology.org/format_3613  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 765  http://edamontology.org/format_3812  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 766  http://edamontology.org/format_3727  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 767  http://edamontology.org/format_1941  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 768  http://edamontology.org/format_3988  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 769  http://edamontology.org/format_3587  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 770    N19fa0d641eba4d02bc63bea1baaf0857         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 771  http://edamontology.org/format_3970  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 772  http://edamontology.org/format_3826  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 773  http://edamontology.org/format_3250  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d5a9eff091b42b5a7e565c4b0f5555c
# 774  http://edamontology.org/format_2306  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 775    N454c11ef5b044f70a6528e606501b75c     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_2536
# 776  http://edamontology.org/format_1958  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 777    Nd4c93ae1aa8d45d6b077d5bb618537ac  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 778  http://edamontology.org/format_3161  http://www.w3.org/2000/01/rdf-schema#subClassOf          N1c68632337284886b39419bdb2d6447a
# 779  http://edamontology.org/format_1998  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 780    N368fe0842d9147e792f2b89c9fadd4a1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 781  http://edamontology.org/format_3551  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6a94bccb14ab4e4a90f2257e822abf77
# 782  http://edamontology.org/format_1551  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0a5dd4778674433cb8e435f1bbcc1de7
# 783  http://edamontology.org/format_3834  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 784    N255b458cf65342d9a497ddddd5912770  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 785    N3447fcc421a340ff9e376e3f6e0cbf1b         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 786  http://edamontology.org/format_1979  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 787  http://edamontology.org/format_1736  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3447fcc421a340ff9e376e3f6e0cbf1b
# 788    Ndd79e61007b349d991b0d43e33f05e59  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 789  http://edamontology.org/format_2206  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 790  http://edamontology.org/format_3239  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nfa2c11aaa1d248c3aafc1eecf3f05fe3
# 791  http://edamontology.org/format_2200  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 792  http://edamontology.org/format_3976  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ndddd34a33f3949148b10d924aeb241e1
# 793  http://edamontology.org/format_1332  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 794  http://edamontology.org/format_3854  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 795  http://edamontology.org/format_3771  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 796  http://edamontology.org/format_1938  http://www.w3.org/2000/01/rdf-schema#subClassOf          N75a240cf6b9943ea86a081ad9edc3901
# 797  http://edamontology.org/format_3608  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 798  http://edamontology.org/format_1393  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 799  http://edamontology.org/format_1737  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3447fcc421a340ff9e376e3f6e0cbf1b
# 800  http://edamontology.org/format_2607  http://www.w3.org/2000/01/rdf-schema#subClassOf          N9bc78ee2de4d45d08e7bf0b5ca4a1f8d
# 801  http://edamontology.org/format_3590  http://www.w3.org/2000/01/rdf-schema#subClassOf          N6d3d10d4b7f94b6ea3698380712986e1
# 802  http://edamontology.org/format_3011  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 803    Nd1e5c10f31da4b99b437c8670f275a1b         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 804  http://edamontology.org/format_2552  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 805  http://edamontology.org/format_1923  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 806  http://edamontology.org/format_3951  http://www.w3.org/2000/01/rdf-schema#subClassOf          Ne91d4d6c066947f7ae73ea6120fba180
# 807  http://edamontology.org/format_3827  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 808  http://edamontology.org/format_1199  http://www.w3.org/2000/01/rdf-schema#subClassOf          N519e070397734f15b7720a53f5d35b1a
# 809  http://edamontology.org/format_3331  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d8a8879c100415fb46ec3c6edc4dbd5
# 810  http://edamontology.org/format_3772  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 811    N0a5dd4778674433cb8e435f1bbcc1de7  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 812  http://edamontology.org/format_3003  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 813  http://edamontology.org/format_2572  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 814  http://edamontology.org/format_3916  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nbf317b198ffa4cae8cc82e0c24607a7d
# 815  http://edamontology.org/format_3156  http://www.w3.org/2000/01/rdf-schema#subClassOf          N31b8c162f92147dfa46f573214c46bc1
# 816    Ndb79d885c863409597ee4c5977d667f6  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 817    Nca57f1b1d3da4bf48fae48d19910cd80  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 818  http://edamontology.org/format_3784  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nfcaab861353744fd9d5af10bec0b8b15
# 819    N72002b38e4bd432aa779b309338f63f8         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 820    Neac21c0661cd40f28af81702bb52d7bd         http://www.w3.org/2002/07/owl#onProperty       http://edamontology.org/is_format_of
# 821    Nc9e2b1f7e87649928e37111d8ae441b1     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1255
# 822  http://edamontology.org/format_1629  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 823  http://edamontology.org/format_2573  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nae710a1ac1b1447ab0325c139674e1c1
# 824  http://edamontology.org/format_3249  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3d5a9eff091b42b5a7e565c4b0f5555c
# 825  http://edamontology.org/format_3012  http://www.w3.org/2000/01/rdf-schema#subClassOf          N0e6c1f7eecbe4796b6b8d12a5038f649
# 826  http://edamontology.org/format_1984  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 827  http://edamontology.org/format_3610  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 828  http://edamontology.org/format_3951  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nadb5459110ec4dff87b7968b1072df2f
# 829  http://edamontology.org/format_3328  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc0dc52b4cbed4515bb1f83b4df84a4a3
# 830    Nadff97c82cf8418fbdb0bd146ca96813  http://www.w3.org/1999/02/22-rdf-syntax-ns#type  http://www.w3.org/2002/07/owl#Restriction
# 831  http://edamontology.org/format_1970  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 832  http://edamontology.org/format_2039  http://www.w3.org/2000/01/rdf-schema#subClassOf          Na3fa05840d66414b8d51199520183ea7
# 833    N255b458cf65342d9a497ddddd5912770     http://www.w3.org/2002/07/owl#someValuesFrom          http://edamontology.org/data_1442
# 834  http://edamontology.org/format_1632  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 835  http://edamontology.org/format_3609  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc2db35983c5140d08b979b58ad9732d8
# 836  http://edamontology.org/format_3327  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd4c93ae1aa8d45d6b077d5bb618537ac
# 837  http://edamontology.org/format_3607  http://www.w3.org/2000/01/rdf-schema#subClassOf          N19fa0d641eba4d02bc63bea1baaf0857
# 838  http://edamontology.org/format_2305  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 839  http://edamontology.org/format_3164  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 840  http://edamontology.org/format_3650  http://www.w3.org/2000/01/rdf-schema#subClassOf          N454c11ef5b044f70a6528e606501b75c
# 841  http://edamontology.org/format_1952  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nd1f6d47a6c284630b1f2490ddf0b6970
# 842  http://edamontology.org/format_1360  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3a4175c1465a43e6b6743de13fa7d1d6
# 843  http://edamontology.org/format_1939  http://www.w3.org/2000/01/rdf-schema#subClassOf          Nc9e2b1f7e87649928e37111d8ae441b1
# 844  http://edamontology.org/format_1734  http://www.w3.org/2000/01/rdf-schema#subClassOf          N3447fcc421a340ff9e376e3f6e0cbf1b

# %%
print(str(len(g)) + ' triples in the EDAM triple store')
# Out:
# 38602 triples in the EDAM triple store

# %% [markdown]
# ## Run query 2 after adding the "infered" triplets

# %%
results = g.query(q2)
print(f"nb formats with is_format_of property: {len(results)} ")
df = pd.DataFrame(columns=["entity","label","data"])
for r in results:
        pd.set_option("display.max_rows",None,"display.max_colwidth",5000,"display.width",5000,)
        concept = pd.DataFrame([[r["entity"], r["label"], r["data"]]],columns=["entity","label","data"])
        df=pd.concat([df, concept], ignore_index=True)
df.index = np.arange(1, len(df) + 1)
display(df)
# Out:
# nb formats with is_format_of property: 732
#                                   entity                                                  label                               data
# 1    http://edamontology.org/format_1475                              PDB database entry format  http://edamontology.org/data_0883
# 2    http://edamontology.org/format_1951                                             pdbatomnuc  http://edamontology.org/data_0883
# 3    http://edamontology.org/format_4035                                                    PQR  http://edamontology.org/data_0883
# 4    http://edamontology.org/format_1950                                                pdbatom  http://edamontology.org/data_0883
# 5    http://edamontology.org/format_1953                                              pdbseqres  http://edamontology.org/data_0883
# 6    http://edamontology.org/format_1477                                                  mmCIF  http://edamontology.org/data_0883
# 7    http://edamontology.org/format_4036                                                  PDBQT  http://edamontology.org/data_0883
# 8    http://edamontology.org/format_1478                                                  PDBML  http://edamontology.org/data_0883
# 9    http://edamontology.org/format_1476                                                    PDB  http://edamontology.org/data_0883
# 10   http://edamontology.org/format_1952                                           pdbseqresnuc  http://edamontology.org/data_0883
# 11   http://edamontology.org/format_1475                              PDB database entry format  http://edamontology.org/data_3870
# 12   http://edamontology.org/format_1953                                              pdbseqres  http://edamontology.org/data_3870
# 13   http://edamontology.org/format_1951                                             pdbatomnuc  http://edamontology.org/data_3870
# 14   http://edamontology.org/format_1477                                                  mmCIF  http://edamontology.org/data_3870
# 15   http://edamontology.org/format_4036                                                  PDBQT  http://edamontology.org/data_3870
# 16   http://edamontology.org/format_1950                                                pdbatom  http://edamontology.org/data_3870
# 17   http://edamontology.org/format_1476                                                    PDB  http://edamontology.org/data_3870
# 18   http://edamontology.org/format_1478                                                  PDBML  http://edamontology.org/data_3870
# 19   http://edamontology.org/format_1952                                           pdbseqresnuc  http://edamontology.org/data_3870
# 20   http://edamontology.org/format_4035                                                    PQR  http://edamontology.org/data_3870
# 21   http://edamontology.org/format_1637                                                    dat  http://edamontology.org/data_1714
# 22   http://edamontology.org/format_1638                                                    cel  http://edamontology.org/data_3110
# 23   http://edamontology.org/format_1644                                                    CHP  http://edamontology.org/data_3111
# 24   http://edamontology.org/format_1919                                 Sequence record format  http://edamontology.org/data_0849
# 25   http://edamontology.org/format_3826                                                 proBAM  http://edamontology.org/data_0849
# 26   http://edamontology.org/format_3770                                          UniProtKB XML  http://edamontology.org/data_0849
# 27   http://edamontology.org/format_3608                                             qualsolexa  http://edamontology.org/data_0849
# 28   http://edamontology.org/format_1927                                            EMBL format  http://edamontology.org/data_0849
# 29   http://edamontology.org/format_1629                                                   mira  http://edamontology.org/data_0849
# 30   http://edamontology.org/format_1937                                                genpept  http://edamontology.org/data_0849
# 31   http://edamontology.org/format_3609                                           qualillumina  http://edamontology.org/data_0849
# 32   http://edamontology.org/format_1998                                      PHYLIP sequential  http://edamontology.org/data_0849
# 33   http://edamontology.org/format_3485                                                    RSF  http://edamontology.org/data_0849
# 34   http://edamontology.org/format_2573                                                    SAM  http://edamontology.org/data_0849
# 35   http://edamontology.org/format_1945                                            mase format  http://edamontology.org/data_0849
# 36   http://edamontology.org/format_1944                                             jackknifer  http://edamontology.org/data_0849
# 37   http://edamontology.org/format_2559                                    GenBank-like format  http://edamontology.org/data_0849
# 38   http://edamontology.org/format_2181                                       EMBL-like (text)  http://edamontology.org/data_0849
# 39   http://edamontology.org/format_3820                              Relaxed PHYLIP Sequential  http://edamontology.org/data_0849
# 40   http://edamontology.org/format_1628                                                    ABI  http://edamontology.org/data_0849
# 41   http://edamontology.org/format_1925                                                 codata  http://edamontology.org/data_0849
# 42   http://edamontology.org/format_1935                                                    GCG  http://edamontology.org/data_0849
# 43   http://edamontology.org/format_3487                                                   BSML  http://edamontology.org/data_0849
# 44   http://edamontology.org/format_3978                                                 CONTIG  http://edamontology.org/data_0849
# 45   http://edamontology.org/format_1968                                                 dasdna  http://edamontology.org/data_0849
# 46   http://edamontology.org/format_1943                                               igstrict  http://edamontology.org/data_0849
# 47   http://edamontology.org/format_1997                                          PHYLIP format  http://edamontology.org/data_0849
# 48   http://edamontology.org/format_2184                                                 cdsxml  http://edamontology.org/data_0849
# 49   http://edamontology.org/format_3281                                                    A2M  http://edamontology.org/data_0849
# 50   http://edamontology.org/format_3312                                                    GDE  http://edamontology.org/data_0849
# 51   http://edamontology.org/format_3771                                          UniProtKB RDF  http://edamontology.org/data_0849
# 52   http://edamontology.org/format_1938                                               GFF2-seq  http://edamontology.org/data_0849
# 53   http://edamontology.org/format_3843                                                  BEAST  http://edamontology.org/data_0849
# 54   http://edamontology.org/format_1951                                             pdbatomnuc  http://edamontology.org/data_0849
# 55   http://edamontology.org/format_1962                                         strider format  http://edamontology.org/data_0849
# 56   http://edamontology.org/format_2545                                      FASTQ-like format  http://edamontology.org/data_0849
# 57   http://edamontology.org/format_3018                                                    ZTR  http://edamontology.org/data_0849
# 58   http://edamontology.org/format_2183                                                EMBLXML  http://edamontology.org/data_0849
# 59   http://edamontology.org/format_2310                                             FASTA-HTML  http://edamontology.org/data_0849
# 60   http://edamontology.org/format_2551                          Sequence record format (text)  http://edamontology.org/data_0849
# 61   http://edamontology.org/format_2204                                      EMBL format (XML)  http://edamontology.org/data_0849
# 62   http://edamontology.org/format_1936                                         GenBank format  http://edamontology.org/data_0849
# 63   http://edamontology.org/format_1926                                                   dbid  http://edamontology.org/data_0849
# 64   http://edamontology.org/format_2311                                              EMBL-HTML  http://edamontology.org/data_0849
# 65   http://edamontology.org/format_1954                                         Pearson format  http://edamontology.org/data_0849
# 66   http://edamontology.org/format_2558                                        EMBL-like (XML)  http://edamontology.org/data_0849
# 67   http://edamontology.org/format_3284                                                    SFF  http://edamontology.org/data_0849
# 68   http://edamontology.org/format_1391                                              HMMER-aln  http://edamontology.org/data_0849
# 69   http://edamontology.org/format_2546                                             FASTA-like  http://edamontology.org/data_0849
# 70   http://edamontology.org/format_2547                                  uniprotkb-like format  http://edamontology.org/data_0849
# 71   http://edamontology.org/format_2185                                                INSDSeq  http://edamontology.org/data_0849
# 72   http://edamontology.org/format_3852                                                 SeqXML  http://edamontology.org/data_0849
# 73   http://edamontology.org/format_1946                                               mega-seq  http://edamontology.org/data_0849
# 74   http://edamontology.org/format_2000                                                  selex  http://edamontology.org/data_0849
# 75   http://edamontology.org/format_1992                                                meganon  http://edamontology.org/data_0849
# 76   http://edamontology.org/format_1973                                               nexusnon  http://edamontology.org/data_0849
# 77   http://edamontology.org/format_3611                                                qual454  http://edamontology.org/data_0849
# 78   http://edamontology.org/format_3844                                              Chado-XML  http://edamontology.org/data_0849
# 79   http://edamontology.org/format_1950                                                pdbatom  http://edamontology.org/data_0849
# 80   http://edamontology.org/format_3850                                               OrthoXML  http://edamontology.org/data_0849
# 81   http://edamontology.org/format_1949                                              nexus-seq  http://edamontology.org/data_0849
# 82   http://edamontology.org/format_1967                                             DAS format  http://edamontology.org/data_0849
# 83   http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_0849
# 84   http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_0849
# 85   http://edamontology.org/format_2923                                           mega variant  http://edamontology.org/data_0849
# 86   http://edamontology.org/format_1953                                              pdbseqres  http://edamontology.org/data_0849
# 87   http://edamontology.org/format_2924                                  Phylip format variant  http://edamontology.org/data_0849
# 88   http://edamontology.org/format_3486                                     GCG format variant  http://edamontology.org/data_0849
# 89   http://edamontology.org/format_1933                                           FASTQ-solexa  http://edamontology.org/data_0849
# 90   http://edamontology.org/format_1960                                          Staden format  http://edamontology.org/data_0849
# 91   http://edamontology.org/format_2543                                       EMBL-like format  http://edamontology.org/data_0849
# 92   http://edamontology.org/format_3000                                                    AB1  http://edamontology.org/data_0849
# 93   http://edamontology.org/format_2057                                  Sequence trace format  http://edamontology.org/data_0849
# 94   http://edamontology.org/format_1942                                                     ig  http://edamontology.org/data_0849
# 95   http://edamontology.org/format_1633                                                    PHD  http://edamontology.org/data_0849
# 96   http://edamontology.org/format_1947                                                GCG MSF  http://edamontology.org/data_0849
# 97   http://edamontology.org/format_2187                                    UniProt-like (text)  http://edamontology.org/data_0849
# 98   http://edamontology.org/format_2182                               FASTQ-like format (text)  http://edamontology.org/data_0849
# 99   http://edamontology.org/format_1930                                                  FASTQ  http://edamontology.org/data_0849
# 100  http://edamontology.org/format_2205                             GenBank-like format (text)  http://edamontology.org/data_0849
# 101  http://edamontology.org/format_3819                             Relaxed PHYLIP Interleaved  http://edamontology.org/data_0849
# 102  http://edamontology.org/format_2532                                           GenBank-HTML  http://edamontology.org/data_0849
# 103  http://edamontology.org/format_1939                                               GFF3-seq  http://edamontology.org/data_0849
# 104  http://edamontology.org/format_1966                                  ASN.1 sequence format  http://edamontology.org/data_0849
# 105  http://edamontology.org/format_1991                                                   mega  http://edamontology.org/data_0849
# 106  http://edamontology.org/format_3607                                                   qual  http://edamontology.org/data_0849
# 107  http://edamontology.org/format_3589                                                csfasta  http://edamontology.org/data_0849
# 108  http://edamontology.org/format_1932                                           FASTQ-sanger  http://edamontology.org/data_0849
# 109  http://edamontology.org/format_1969                                              debug-seq  http://edamontology.org/data_0849
# 110  http://edamontology.org/format_1963                                       UniProtKB format  http://edamontology.org/data_0849
# 111  http://edamontology.org/format_3017                                                    SRF  http://edamontology.org/data_0849
# 112  http://edamontology.org/format_2186                                                geneseq  http://edamontology.org/data_0849
# 113  http://edamontology.org/format_3811                                                   XMFA  http://edamontology.org/data_0849
# 114  http://edamontology.org/format_1940                                         giFASTA format  http://edamontology.org/data_0849
# 115  http://edamontology.org/format_1931                                         FASTQ-illumina  http://edamontology.org/data_0849
# 116  http://edamontology.org/format_1928                               Staden experiment format  http://edamontology.org/data_0849
# 117  http://edamontology.org/format_2005                                            TreeCon-seq  http://edamontology.org/data_0849
# 118  http://edamontology.org/format_1972                                            NCBI format  http://edamontology.org/data_0849
# 119  http://edamontology.org/format_1929                                                  FASTA  http://edamontology.org/data_0849
# 120  http://edamontology.org/format_1934                                          fitch program  http://edamontology.org/data_0849
# 121  http://edamontology.org/format_1941                                               hennig86  http://edamontology.org/data_0849
# 122  http://edamontology.org/format_1958                                                refseqp  http://edamontology.org/data_0849
# 123  http://edamontology.org/format_2200                                      FASTA-like (text)  http://edamontology.org/data_0849
# 124  http://edamontology.org/format_2552                           Sequence record format (XML)  http://edamontology.org/data_0849
# 125  http://edamontology.org/format_1923                                                  acedb  http://edamontology.org/data_0849
# 126  http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_0849
# 127  http://edamontology.org/format_2572                                                    BAM  http://edamontology.org/data_0849
# 128  http://edamontology.org/format_1984                                              FASTA-aln  http://edamontology.org/data_0849
# 129  http://edamontology.org/format_3610                                              qualsolid  http://edamontology.org/data_0849
# 130  http://edamontology.org/format_1970                                          jackknifernon  http://edamontology.org/data_0849
# 131  http://edamontology.org/format_1632                                                    SCF  http://edamontology.org/data_0849
# 132  http://edamontology.org/format_1952                                           pdbseqresnuc  http://edamontology.org/data_0849
# 133  http://edamontology.org/format_1920                     Sequence feature annotation format  http://edamontology.org/data_1255
# 134  http://edamontology.org/format_3008                                                    MAF  http://edamontology.org/data_1255
# 135  http://edamontology.org/format_3612                                     ENCODE peak format  http://edamontology.org/data_1255
# 136  http://edamontology.org/format_3776                                                 BTrack  http://edamontology.org/data_1255
# 137  http://edamontology.org/format_1975                                                   GFF3  http://edamontology.org/data_1255
# 138  http://edamontology.org/format_3613                              ENCODE narrow peak format  http://edamontology.org/data_1255
# 139  http://edamontology.org/format_3587                                              chrominfo  http://edamontology.org/data_1255
# 140  http://edamontology.org/format_3851                                                  PSDML  http://edamontology.org/data_1255
# 141  http://edamontology.org/format_3775                                                 GSuite  http://edamontology.org/data_1255
# 142  http://edamontology.org/format_3011                                               genePred  http://edamontology.org/data_1255
# 143  http://edamontology.org/format_3827                                                 proBED  http://edamontology.org/data_1255
# 144  http://edamontology.org/format_3003                                                    BED  http://edamontology.org/data_1255
# 145  http://edamontology.org/format_2547                                  uniprotkb-like format  http://edamontology.org/data_1255
# 146  http://edamontology.org/format_3012                                                  pgSnp  http://edamontology.org/data_1255
# 147  http://edamontology.org/format_1978                                                 DASGFF  http://edamontology.org/data_1255
# 148  http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_1255
# 149  http://edamontology.org/format_2553                    Sequence feature table format (XML)  http://edamontology.org/data_1255
# 150  http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_1255
# 151  http://edamontology.org/format_3583                                               bedgraph  http://edamontology.org/data_1255
# 152  http://edamontology.org/format_2187                                    UniProt-like (text)  http://edamontology.org/data_1255
# 153  http://edamontology.org/format_3701                                          Sequin format  http://edamontology.org/data_1255
# 154  http://edamontology.org/format_2206                   Sequence feature table format (text)  http://edamontology.org/data_1255
# 155  http://edamontology.org/format_3991                                                TrackDB  http://edamontology.org/data_1255
# 156  http://edamontology.org/format_2305                                                    GFF  http://edamontology.org/data_1255
# 157  http://edamontology.org/format_3164                                                 GTrack  http://edamontology.org/data_1255
# 158  http://edamontology.org/format_1939                                               GFF3-seq  http://edamontology.org/data_1255
# 159  http://edamontology.org/format_3984                                                   QMAP  http://edamontology.org/data_1255
# 160  http://edamontology.org/format_3019                                                    GVF  http://edamontology.org/data_1255
# 161  http://edamontology.org/format_1963                                       UniProtKB format  http://edamontology.org/data_1255
# 162  http://edamontology.org/format_3774                                      BioJSON (Jalview)  http://edamontology.org/data_1255
# 163  http://edamontology.org/format_3586                                                  bed12  http://edamontology.org/data_1255
# 164  http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_1255
# 165  http://edamontology.org/format_3005                                                    WIG  http://edamontology.org/data_1255
# 166  http://edamontology.org/format_3007                                                    PSL  http://edamontology.org/data_1255
# 167  http://edamontology.org/format_1974                                                   GFF2  http://edamontology.org/data_1255
# 168  http://edamontology.org/format_3770                                          UniProtKB XML  http://edamontology.org/data_1255
# 169  http://edamontology.org/format_1927                                            EMBL format  http://edamontology.org/data_1255
# 170  http://edamontology.org/format_3588                                            customtrack  http://edamontology.org/data_1255
# 171  http://edamontology.org/format_3004                                                 bigBed  http://edamontology.org/data_1255
# 172  http://edamontology.org/format_2919                       Sequence annotation track format  http://edamontology.org/data_1255
# 173  http://edamontology.org/format_3853                                            UniParc XML  http://edamontology.org/data_1255
# 174  http://edamontology.org/format_3864                                                mirGFF3  http://edamontology.org/data_1255
# 175  http://edamontology.org/format_1936                                         GenBank format  http://edamontology.org/data_1255
# 176  http://edamontology.org/format_2548                          Sequence feature table format  http://edamontology.org/data_1255
# 177  http://edamontology.org/format_3006                                                 bigWig  http://edamontology.org/data_1255
# 178  http://edamontology.org/format_3983                                                    NET  http://edamontology.org/data_1255
# 179  http://edamontology.org/format_3585                                                   bed6  http://edamontology.org/data_1255
# 180  http://edamontology.org/format_3584                                              bedstrict  http://edamontology.org/data_1255
# 181  http://edamontology.org/format_3614                               ENCODE broad peak format  http://edamontology.org/data_1255
# 182  http://edamontology.org/format_3812                                                    GEN  http://edamontology.org/data_1255
# 183  http://edamontology.org/format_2306                                                    GTF  http://edamontology.org/data_1255
# 184  http://edamontology.org/format_1979                                             debug-feat  http://edamontology.org/data_1255
# 185  http://edamontology.org/format_3854                                             UniRef XML  http://edamontology.org/data_1255
# 186  http://edamontology.org/format_3771                                          UniProtKB RDF  http://edamontology.org/data_1255
# 187  http://edamontology.org/format_1938                                               GFF2-seq  http://edamontology.org/data_1255
# 188  http://edamontology.org/format_1921                                       Alignment format  http://edamontology.org/data_0863
# 189  http://edamontology.org/format_1961                                       Stockholm format  http://edamontology.org/data_0863
# 190  http://edamontology.org/format_3820                              Relaxed PHYLIP Sequential  http://edamontology.org/data_0863
# 191  http://edamontology.org/format_1391                                              HMMER-aln  http://edamontology.org/data_0863
# 192  http://edamontology.org/format_2000                                                  selex  http://edamontology.org/data_0863
# 193  http://edamontology.org/format_1992                                                meganon  http://edamontology.org/data_0863
# 194  http://edamontology.org/format_1973                                               nexusnon  http://edamontology.org/data_0863
# 195  http://edamontology.org/format_3845                                                  HSAML  http://edamontology.org/data_0863
# 196  http://edamontology.org/format_1949                                              nexus-seq  http://edamontology.org/data_0863
# 197  http://edamontology.org/format_1986                                                 markx1  http://edamontology.org/data_0863
# 198  http://edamontology.org/format_3157                             EBI Application Result XML  http://edamontology.org/data_0863
# 199  http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_0863
# 200  http://edamontology.org/format_1985                                                 markx0  http://edamontology.org/data_0863
# 201  http://edamontology.org/format_2352                                           BioXSD (XML)  http://edamontology.org/data_0863
# 202  http://edamontology.org/format_3330                                                     PO  http://edamontology.org/data_0863
# 203  http://edamontology.org/format_2923                                           mega variant  http://edamontology.org/data_0863
# 204  http://edamontology.org/format_2924                                  Phylip format variant  http://edamontology.org/data_0863
# 205  http://edamontology.org/format_3486                                     GCG format variant  http://edamontology.org/data_0863
# 206  http://edamontology.org/format_3013                                                    axt  http://edamontology.org/data_0863
# 207  http://edamontology.org/format_1982                                        ClustalW format  http://edamontology.org/data_0863
# 208  http://edamontology.org/format_1947                                                GCG MSF  http://edamontology.org/data_0863
# 209  http://edamontology.org/format_1983                                                  debug  http://edamontology.org/data_0863
# 210  http://edamontology.org/format_3819                             Relaxed PHYLIP Interleaved  http://edamontology.org/data_0863
# 211  http://edamontology.org/format_3311                                                  RNAML  http://edamontology.org/data_0863
# 212  http://edamontology.org/format_1991                                                   mega  http://edamontology.org/data_0863
# 213  http://edamontology.org/format_1990                                                  match  http://edamontology.org/data_0863
# 214  http://edamontology.org/format_3313                                                    BLC  http://edamontology.org/data_0863
# 215  http://edamontology.org/format_3811                                                   XMFA  http://edamontology.org/data_0863
# 216  http://edamontology.org/format_3015                                                 Pileup  http://edamontology.org/data_0863
# 217  http://edamontology.org/format_2004                                        T-Coffee format  http://edamontology.org/data_0863
# 218  http://edamontology.org/format_2922                                         markx0 variant  http://edamontology.org/data_0863
# 219  http://edamontology.org/format_2005                                            TreeCon-seq  http://edamontology.org/data_0863
# 220  http://edamontology.org/format_1929                                                  FASTA  http://edamontology.org/data_0863
# 221  http://edamontology.org/format_1987                                                markx10  http://edamontology.org/data_0863
# 222  http://edamontology.org/format_1392                                         DIALIGN format  http://edamontology.org/data_0863
# 223  http://edamontology.org/format_2001                                   EMBOSS simple format  http://edamontology.org/data_0863
# 224  http://edamontology.org/format_3849                                                  MSAML  http://edamontology.org/data_0863
# 225  http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_0863
# 226  http://edamontology.org/format_3014                                                    LAV  http://edamontology.org/data_0863
# 227  http://edamontology.org/format_2572                                                    BAM  http://edamontology.org/data_0863
# 228  http://edamontology.org/format_1984                                              FASTA-aln  http://edamontology.org/data_0863
# 229  http://edamontology.org/format_3826                                                 proBAM  http://edamontology.org/data_0863
# 230  http://edamontology.org/format_2554                                Alignment format (text)  http://edamontology.org/data_0863
# 231  http://edamontology.org/format_1999                                          scores format  http://edamontology.org/data_0863
# 232  http://edamontology.org/format_2555                                 Alignment format (XML)  http://edamontology.org/data_0863
# 233  http://edamontology.org/format_3485                                                    RSF  http://edamontology.org/data_0863
# 234  http://edamontology.org/format_2002                                             srs format  http://edamontology.org/data_0863
# 235  http://edamontology.org/format_2003                                                srspair  http://edamontology.org/data_0863
# 236  http://edamontology.org/format_3589                                                csfasta  http://edamontology.org/data_0863
# 237  http://edamontology.org/format_1996                                                   pair  http://edamontology.org/data_0863
# 238  http://edamontology.org/format_3992                                           CIGAR format  http://edamontology.org/data_0863
# 239  http://edamontology.org/format_3462                                                   CRAM  http://edamontology.org/data_0863
# 240  http://edamontology.org/format_1935                                                    GCG  http://edamontology.org/data_0863
# 241  http://edamontology.org/format_3774                                      BioJSON (Jalview)  http://edamontology.org/data_0863
# 242  http://edamontology.org/format_2920                           Alignment format (pair only)  http://edamontology.org/data_0863
# 243  http://edamontology.org/format_1997                                          PHYLIP format  http://edamontology.org/data_0863
# 244  http://edamontology.org/format_3982                                                  CHAIN  http://edamontology.org/data_0863
# 245  http://edamontology.org/format_3281                                                    A2M  http://edamontology.org/data_0863
# 246  http://edamontology.org/format_1989                                                 markx3  http://edamontology.org/data_0863
# 247  http://edamontology.org/format_3007                                                    PSL  http://edamontology.org/data_0863
# 248  http://edamontology.org/format_1988                                                 markx2  http://edamontology.org/data_0863
# 249  http://edamontology.org/format_3008                                                    MAF  http://edamontology.org/data_0863
# 250  http://edamontology.org/format_3830                                                    ARB  http://edamontology.org/data_0863
# 251  http://edamontology.org/format_1998                                      PHYLIP sequential  http://edamontology.org/data_0863
# 252  http://edamontology.org/format_1393                                                    daf  http://edamontology.org/data_0863
# 253  http://edamontology.org/format_2573                                                    SAM  http://edamontology.org/data_0863
# 254  http://edamontology.org/format_2006                               Phylogenetic tree format  http://edamontology.org/data_0872
# 255  http://edamontology.org/format_3159                                               phyloXML  http://edamontology.org/data_0872
# 256  http://edamontology.org/format_1424                                    ClustalW dendrogram  http://edamontology.org/data_0872
# 257  http://edamontology.org/format_1437                                         TreeFam format  http://edamontology.org/data_0872
# 258  http://edamontology.org/format_1912                                           Nexus format  http://edamontology.org/data_0872
# 259  http://edamontology.org/format_1910                                                 newick  http://edamontology.org/data_0872
# 260  http://edamontology.org/format_1436                                        TreeBASE format  http://edamontology.org/data_0872
# 261  http://edamontology.org/format_3160                                                  NeXML  http://edamontology.org/data_0872
# 262  http://edamontology.org/format_1425                                        Phylip tree raw  http://edamontology.org/data_0872
# 263  http://edamontology.org/format_2556                        Phylogenetic tree format (text)  http://edamontology.org/data_0872
# 264  http://edamontology.org/format_1911                                         TreeCon format  http://edamontology.org/data_0872
# 265  http://edamontology.org/format_2557                         Phylogenetic tree format (XML)  http://edamontology.org/data_0872
# 266  http://edamontology.org/format_1435                                     Phylip tree format  http://edamontology.org/data_0872
# 267  http://edamontology.org/format_2013                   Biological pathway or network format  http://edamontology.org/data_2600
# 268  http://edamontology.org/format_3822                                                    GML  http://edamontology.org/data_2600
# 269  http://edamontology.org/format_3692                                                SBGN-ML  http://edamontology.org/data_2600
# 270  http://edamontology.org/format_3686                                           COMBINE OMEX  http://edamontology.org/data_2600
# 271  http://edamontology.org/format_3239                                               CopasiML  http://edamontology.org/data_2600
# 272  http://edamontology.org/format_3619                                                    sif  http://edamontology.org/data_2600
# 273  http://edamontology.org/format_3972                                                   BNGL  http://edamontology.org/data_2600
# 274  http://edamontology.org/format_3821                                                  VisML  http://edamontology.org/data_2600
# 275  http://edamontology.org/format_3689                                                   BCML  http://edamontology.org/data_2600
# 276  http://edamontology.org/format_3688                                                  SBtab  http://edamontology.org/data_2600
# 277  http://edamontology.org/format_3847                                                   KGML  http://edamontology.org/data_2600
# 278  http://edamontology.org/format_3240                                                 CellML  http://edamontology.org/data_2600
# 279  http://edamontology.org/format_3657                                                   GPML  http://edamontology.org/data_2600
# 280  http://edamontology.org/format_3971                                                NeuroML  http://edamontology.org/data_2600
# 281  http://edamontology.org/format_2585                                                   SBML  http://edamontology.org/data_2600
# 282  http://edamontology.org/format_3156                                                 BioPAX  http://edamontology.org/data_2600
# 283  http://edamontology.org/format_2014                      Sequence-profile alignment format  http://edamontology.org/data_0858
# 284  http://edamontology.org/format_1422         HMMER profile alignment (HMM versus sequences)  http://edamontology.org/data_0858
# 285  http://edamontology.org/format_1421        HMMER profile alignment (sequences versus HMMs)  http://edamontology.org/data_0858
# 286  http://edamontology.org/format_1419                        Sequence-MEME profile alignment  http://edamontology.org/data_0858
# 287  http://edamontology.org/format_2017                                Amino acid index format  http://edamontology.org/data_1501
# 288  http://edamontology.org/format_1504                                                aaindex  http://edamontology.org/data_1501
# 289  http://edamontology.org/format_2020                                         Article format  http://edamontology.org/data_0971
# 290  http://edamontology.org/format_1739                                                    pmc  http://edamontology.org/data_0971
# 291  http://edamontology.org/format_2194                                                medline  http://edamontology.org/data_0971
# 292  http://edamontology.org/format_2021                              Text mining report format  http://edamontology.org/data_0972
# 293  http://edamontology.org/format_1740                                            iHOP format  http://edamontology.org/data_0972
# 294  http://edamontology.org/format_2027                          Enzyme kinetics report format  http://edamontology.org/data_2024
# 295  http://edamontology.org/format_1582                                                 findkm  http://edamontology.org/data_2024
# 296  http://edamontology.org/format_2030                                   Chemical data format  http://edamontology.org/data_0962
# 297  http://edamontology.org/format_3814                                                    SDF  http://edamontology.org/data_0962
# 298  http://edamontology.org/format_3816                                                   Mol2  http://edamontology.org/data_0962
# 299  http://edamontology.org/format_4023                                                    cml  http://edamontology.org/data_0962
# 300  http://edamontology.org/format_3815                                                Molfile  http://edamontology.org/data_0962
# 301  http://edamontology.org/format_1705                      HET group dictionary entry format  http://edamontology.org/data_0962
# 302  http://edamontology.org/format_4024                                                    cif  http://edamontology.org/data_0962
# 303  http://edamontology.org/format_3951                                                BcForms  http://edamontology.org/data_0962
# 304  http://edamontology.org/format_2031                                 Gene annotation format  http://edamontology.org/data_0916
# 305  http://edamontology.org/format_3979                                                   WEGO  http://edamontology.org/data_0916
# 306  http://edamontology.org/format_1316                                      est2genome format  http://edamontology.org/data_0916
# 307  http://edamontology.org/format_3850                                               OrthoXML  http://edamontology.org/data_0916
# 308  http://edamontology.org/format_2035                                Chemical formula format  http://edamontology.org/data_0846
# 309  http://edamontology.org/format_3909                                                BpForms  http://edamontology.org/data_0846
# 310  http://edamontology.org/format_1200                                                 smarts  http://edamontology.org/data_0846
# 311  http://edamontology.org/format_1198                                                     mf  http://edamontology.org/data_0846
# 312  http://edamontology.org/format_1196                                                 SMILES  http://edamontology.org/data_0846
# 313  http://edamontology.org/format_1197                                                  InChI  http://edamontology.org/data_0846
# 314  http://edamontology.org/format_1199                                               InChIKey  http://edamontology.org/data_0846
# 315  http://edamontology.org/format_2036                     Phylogenetic character data format  http://edamontology.org/data_0871
# 316  http://edamontology.org/format_2037  Phylogenetic continuous quantitative character format  http://edamontology.org/data_0871
# 317  http://edamontology.org/format_2038                    Phylogenetic discrete states format  http://edamontology.org/data_0871
# 318  http://edamontology.org/format_2040           Phylogenetic tree report (invariants) format  http://edamontology.org/data_0871
# 319  http://edamontology.org/format_1430              Phylip continuous quantitative characters  http://edamontology.org/data_0871
# 320  http://edamontology.org/format_1432                    Phylip character frequencies format  http://edamontology.org/data_0871
# 321  http://edamontology.org/format_1434                                  Phylip cliques format  http://edamontology.org/data_0871
# 322  http://edamontology.org/format_1433                          Phylip discrete states format  http://edamontology.org/data_0871
# 323  http://edamontology.org/format_2039              Phylogenetic tree report (cliques) format  http://edamontology.org/data_0871
# 324  http://edamontology.org/format_2037  Phylogenetic continuous quantitative character format  http://edamontology.org/data_1426
# 325  http://edamontology.org/format_1430              Phylip continuous quantitative characters  http://edamontology.org/data_1426
# 326  http://edamontology.org/format_1432                    Phylip character frequencies format  http://edamontology.org/data_1426
# 327  http://edamontology.org/format_2038                    Phylogenetic discrete states format  http://edamontology.org/data_1427
# 328  http://edamontology.org/format_1433                          Phylip discrete states format  http://edamontology.org/data_1427
# 329  http://edamontology.org/format_2039              Phylogenetic tree report (cliques) format  http://edamontology.org/data_1428
# 330  http://edamontology.org/format_1434                                  Phylip cliques format  http://edamontology.org/data_1428
# 331  http://edamontology.org/format_2040           Phylogenetic tree report (invariants) format  http://edamontology.org/data_1429
# 332  http://edamontology.org/format_2049       Phylogenetic tree report (tree distances) format  http://edamontology.org/data_1442
# 333  http://edamontology.org/format_1445                            Phylip tree distance format  http://edamontology.org/data_1442
# 334  http://edamontology.org/format_2052                           Protein family report format  http://edamontology.org/data_0907
# 335  http://edamontology.org/format_2054                             Protein interaction format  http://edamontology.org/data_0906
# 336  http://edamontology.org/format_3242                                     PSI MI TAB (MITAB)  http://edamontology.org/data_0906
# 337  http://edamontology.org/format_3158                                       PSI MI XML (MIF)  http://edamontology.org/data_0906
# 338  http://edamontology.org/format_3243                                                PSI-PAR  http://edamontology.org/data_0906
# 339  http://edamontology.org/format_2304                              STRING entry format (XML)  http://edamontology.org/data_0906
# 340  http://edamontology.org/format_2055                               Sequence assembly format  http://edamontology.org/data_0925
# 341  http://edamontology.org/format_3693                                                    AGP  http://edamontology.org/data_0925
# 342  http://edamontology.org/format_3582                                                    afg  http://edamontology.org/data_0925
# 343  http://edamontology.org/format_3975                                                  GFA 1  http://edamontology.org/data_0925
# 344  http://edamontology.org/format_1631                                                    EXP  http://edamontology.org/data_0925
# 345  http://edamontology.org/format_2561                        Sequence assembly format (text)  http://edamontology.org/data_0925
# 346  http://edamontology.org/format_3001                                                    ACE  http://edamontology.org/data_0925
# 347  http://edamontology.org/format_3818                                           ELAND format  http://edamontology.org/data_0925
# 348  http://edamontology.org/format_3823                                                  FASTG  http://edamontology.org/data_0925
# 349  http://edamontology.org/format_1630                                                    CAF  http://edamontology.org/data_0925
# 350  http://edamontology.org/format_3976                                                  GFA 2  http://edamontology.org/data_0925
# 351  http://edamontology.org/format_2057                                  Sequence trace format  http://edamontology.org/data_0924
# 352  http://edamontology.org/format_2573                                                    SAM  http://edamontology.org/data_0924
# 353  http://edamontology.org/format_1628                                                    ABI  http://edamontology.org/data_0924
# 354  http://edamontology.org/format_1632                                                    SCF  http://edamontology.org/data_0924
# 355  http://edamontology.org/format_2545                                      FASTQ-like format  http://edamontology.org/data_0924
# 356  http://edamontology.org/format_3018                                                    ZTR  http://edamontology.org/data_0924
# 357  http://edamontology.org/format_3284                                                    SFF  http://edamontology.org/data_0924
# 358  http://edamontology.org/format_1933                                           FASTQ-solexa  http://edamontology.org/data_0924
# 359  http://edamontology.org/format_3000                                                    AB1  http://edamontology.org/data_0924
# 360  http://edamontology.org/format_1633                                                    PHD  http://edamontology.org/data_0924
# 361  http://edamontology.org/format_1930                                                  FASTQ  http://edamontology.org/data_0924
# 362  http://edamontology.org/format_3607                                                   qual  http://edamontology.org/data_0924
# 363  http://edamontology.org/format_1932                                           FASTQ-sanger  http://edamontology.org/data_0924
# 364  http://edamontology.org/format_3611                                                qual454  http://edamontology.org/data_0924
# 365  http://edamontology.org/format_3017                                                    SRF  http://edamontology.org/data_0924
# ...
# 611  http://edamontology.org/format_3714                           MaxQuant APL peaklist format  http://edamontology.org/data_2536
# 612  http://edamontology.org/format_3244                                                   mzML  http://edamontology.org/data_2536
# 613  http://edamontology.org/format_3858                                             Waters RAW  http://edamontology.org/data_2536
# 614  http://edamontology.org/format_3684                                              PRIDE XML  http://edamontology.org/data_2536
# 615  http://edamontology.org/format_3248                                              mzQuantML  http://edamontology.org/data_2536
# 616  http://edamontology.org/format_3653                                                    pkl  http://edamontology.org/data_2536
# 617  http://edamontology.org/format_3833                                             featureXML  http://edamontology.org/data_2536
# 618  http://edamontology.org/format_3835                                               TIDE TXT  http://edamontology.org/data_2536
# 619  http://edamontology.org/format_3246                                                  TraML  http://edamontology.org/data_2536
# 620  http://edamontology.org/format_3712                                             Thermo RAW  http://edamontology.org/data_2536
# 621  http://edamontology.org/format_3834                                                 mzData  http://edamontology.org/data_2536
# 622  http://edamontology.org/format_3650                                                 netCDF  http://edamontology.org/data_2536
# 623  http://edamontology.org/format_3326                                      Data index format  http://edamontology.org/data_0955
# 624  http://edamontology.org/format_3624                                               snpeffdb  http://edamontology.org/data_0955
# 625  http://edamontology.org/format_3491                                                  ebwtl  http://edamontology.org/data_0955
# 626  http://edamontology.org/format_3484                                                   ebwt  http://edamontology.org/data_0955
# 627  http://edamontology.org/format_3700                                Tabix index file format  http://edamontology.org/data_0955
# 628  http://edamontology.org/format_3327                                                    BAI  http://edamontology.org/data_0955
# 629  http://edamontology.org/format_3484                                                   ebwt  http://edamontology.org/data_3210
# 630  http://edamontology.org/format_3491                                                  ebwtl  http://edamontology.org/data_3210
# 631  http://edamontology.org/format_3547                                           Image format  http://edamontology.org/data_2968
# 632  http://edamontology.org/format_3592                                                    BMP  http://edamontology.org/data_2968
# 633  http://edamontology.org/format_3990                                                    AVI  http://edamontology.org/data_2968
# 634  http://edamontology.org/format_3596                                                    ppm  http://edamontology.org/data_2968
# 635  http://edamontology.org/format_3598                                                    xbm  http://edamontology.org/data_2968
# 636  http://edamontology.org/format_3550                                                    mhd  http://edamontology.org/data_2968
# 637  http://edamontology.org/format_3604                                                    SVG  http://edamontology.org/data_2968
# 638  http://edamontology.org/format_3969                                                   Vega  http://edamontology.org/data_2968
# 639  http://edamontology.org/format_3600                                                    rgb  http://edamontology.org/data_2968
# 640  http://edamontology.org/format_3549                                                    nii  http://edamontology.org/data_2968
# 641  http://edamontology.org/format_3838                                                   pptx  http://edamontology.org/data_2968
# 642  http://edamontology.org/format_3594                                                    pcd  http://edamontology.org/data_2968
# 643  http://edamontology.org/format_3605                                                   rast  http://edamontology.org/data_2968
# 644  http://edamontology.org/format_3615                                                  bgzip  http://edamontology.org/data_2968
# 645  http://edamontology.org/format_3591                                                   TIFF  http://edamontology.org/data_2968
# 646  http://edamontology.org/format_3603                                                    PNG  http://edamontology.org/data_2968
# 647  http://edamontology.org/format_3597                                                    psd  http://edamontology.org/data_2968
# 648  http://edamontology.org/format_3593                                                     im  http://edamontology.org/data_2968
# 649  http://edamontology.org/format_3599                                                    xpm  http://edamontology.org/data_2968
# 650  http://edamontology.org/format_3993                               Stereolithography format  http://edamontology.org/data_2968
# 651  http://edamontology.org/format_3616                                                  tabix  http://edamontology.org/data_2968
# 652  http://edamontology.org/format_3986                                                    WMV  http://edamontology.org/data_2968
# 653  http://edamontology.org/format_3997                                                 MPEG-4  http://edamontology.org/data_2968
# 654  http://edamontology.org/format_3601                                                    pbm  http://edamontology.org/data_2968
# 655  http://edamontology.org/format_3602                                                    pgm  http://edamontology.org/data_2968
# 656  http://edamontology.org/format_3579                                                    JPG  http://edamontology.org/data_2968
# 657  http://edamontology.org/format_3595                                                    pcx  http://edamontology.org/data_2968
# 658  http://edamontology.org/format_3995                                    Texture file format  http://edamontology.org/data_2968
# 659  http://edamontology.org/format_3548                                           DICOM format  http://edamontology.org/data_2968
# 660  http://edamontology.org/format_3994                                                    U3D  http://edamontology.org/data_2968
# 661  http://edamontology.org/format_3727                                               OME-TIFF  http://edamontology.org/data_2968
# 662  http://edamontology.org/format_3988                                                    LSM  http://edamontology.org/data_2968
# 663  http://edamontology.org/format_3970                                              Vega-lite  http://edamontology.org/data_2968
# 664  http://edamontology.org/format_3551                                                   nrrd  http://edamontology.org/data_2968
# 665  http://edamontology.org/format_3578                                                   IDAT  http://edamontology.org/data_3110
# 666  http://edamontology.org/format_3606                  Sequence quality report format (text)  http://edamontology.org/data_2048
# 667  http://edamontology.org/format_3611                                                qual454  http://edamontology.org/data_2048
# 668  http://edamontology.org/format_3610                                              qualsolid  http://edamontology.org/data_2048
# 669  http://edamontology.org/format_3608                                             qualsolexa  http://edamontology.org/data_2048
# 670  http://edamontology.org/format_3609                                           qualillumina  http://edamontology.org/data_2048
# 671  http://edamontology.org/format_3607                                                   qual  http://edamontology.org/data_2048
# 672  http://edamontology.org/format_3626                                                    MAT  http://edamontology.org/data_1499
# 673  http://edamontology.org/format_3706                               Biodiversity data format  http://edamontology.org/data_3707
# 674  http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_3707
# 675  http://edamontology.org/format_3708                                            ABCD format  http://edamontology.org/data_3707
# 676  http://edamontology.org/format_3746                                            BIOM format  http://edamontology.org/data_3707
# 677  http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_1772
# 678  http://edamontology.org/format_3772                                       BioJSON (BioXSD)  http://edamontology.org/data_3108
# 679  http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_1772
# 680  http://edamontology.org/format_3773                                                BioYAML  http://edamontology.org/data_3108
# 681  http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_2530
# 682  http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_3113
# 683  http://edamontology.org/format_3777                                                   MCPD  http://edamontology.org/data_3567
# 684  http://edamontology.org/format_3780                                  Annotated text format  http://edamontology.org/data_3779
# 685  http://edamontology.org/format_1741                                           OSCAR format  http://edamontology.org/data_3779
# 686  http://edamontology.org/format_3783                                        PubTator format  http://edamontology.org/data_3779
# 687  http://edamontology.org/format_3781                                   PubAnnotation format  http://edamontology.org/data_3779
# 688  http://edamontology.org/format_3785                              BioNLP Shared Task format  http://edamontology.org/data_3779
# 689  http://edamontology.org/format_3782                                                   BioC  http://edamontology.org/data_3779
# 690  http://edamontology.org/format_3784                                 Open Annotation format  http://edamontology.org/data_3779
# 691  http://edamontology.org/format_3787                                         Query language  http://edamontology.org/data_3786
# 692  http://edamontology.org/format_3824                                        NMR data format  http://edamontology.org/data_3488
# 693  http://edamontology.org/format_3906                                               NMReDATA  http://edamontology.org/data_3488
# 694  http://edamontology.org/format_3825                                                  nmrML  http://edamontology.org/data_3488
# 695  http://edamontology.org/format_3828                             Raw microarray data format  http://edamontology.org/data_3110
# 696  http://edamontology.org/format_3829                                                    GPR  http://edamontology.org/data_3110
# 697  http://edamontology.org/format_3866                                      Trajectory format  http://edamontology.org/data_3870
# 698  http://edamontology.org/format_3913                                                   Loom  http://edamontology.org/data_3870
# 699  http://edamontology.org/format_3877                                                    XYZ  http://edamontology.org/data_3870
# 700  http://edamontology.org/format_3878                                                  mdcrd  http://edamontology.org/data_3870
# 701  http://edamontology.org/format_3650                                                 netCDF  http://edamontology.org/data_3870
# 702  http://edamontology.org/format_3876                                                    TNG  http://edamontology.org/data_3870
# 703  http://edamontology.org/format_3885                                                 BinPos  http://edamontology.org/data_3870
# 704  http://edamontology.org/format_3886                                                    RST  http://edamontology.org/data_3870
# 705  http://edamontology.org/format_3868                               Trajectory format (text)  http://edamontology.org/data_3870
# 706  http://edamontology.org/format_3874                                                 PCAzip  http://edamontology.org/data_3870
# 707  http://edamontology.org/format_3873                                                    HDF  http://edamontology.org/data_3870
# 708  http://edamontology.org/format_3875                                                    XTC  http://edamontology.org/data_3870
# 709  http://edamontology.org/format_3867                             Trajectory format (binary)  http://edamontology.org/data_3870
# 710  http://edamontology.org/format_3910                                                    trr  http://edamontology.org/data_3870
# 711  http://edamontology.org/format_3590                                                   HDF5  http://edamontology.org/data_3870
# 712  http://edamontology.org/format_3879                                        Topology format  http://edamontology.org/data_3872
# 713  http://edamontology.org/format_3880                                            GROMACS top  http://edamontology.org/data_3872
# 714  http://edamontology.org/format_3883                                            GROMACS itp  http://edamontology.org/data_3872
# 715  http://edamontology.org/format_3881                                              AMBER top  http://edamontology.org/data_3872
# 716  http://edamontology.org/format_3882                                                    PSF  http://edamontology.org/data_3872
# 717  http://edamontology.org/format_3887                                             CHARMM rtf  http://edamontology.org/data_3872
# 718  http://edamontology.org/format_3884                                    FF parameter format  http://edamontology.org/data_3872
# 719  http://edamontology.org/format_3888                                           AMBER frcmod  http://edamontology.org/data_3872
# 720  http://edamontology.org/format_3889                                              AMBER off  http://edamontology.org/data_3872
# 721  http://edamontology.org/format_3909                                                BpForms  http://edamontology.org/data_1255
# 722  http://edamontology.org/format_3911                                                    msh  http://edamontology.org/data_2190
# 723  http://edamontology.org/format_3913                                                   Loom  http://edamontology.org/data_2535
# 724  http://edamontology.org/format_3913                                                   Loom  http://edamontology.org/data_3112
# 725  http://edamontology.org/format_3915                                                   Zarr  http://edamontology.org/data_2535
# 726  http://edamontology.org/format_3915                                                   Zarr  http://edamontology.org/data_3112
# 727  http://edamontology.org/format_3916                                                    MTX  http://edamontology.org/data_2535
# 728  http://edamontology.org/format_3916                                                    MTX  http://edamontology.org/data_3112
# 729  http://edamontology.org/format_3971                                                NeuroML  http://edamontology.org/data_3241
# 730  http://edamontology.org/format_3972                                                   BNGL  http://edamontology.org/data_3241
# 731  http://edamontology.org/format_4015                                                  PEtab  http://edamontology.org/data_3869
# 732  http://edamontology.org/format_4024                                                    cif  http://edamontology.org/data_0883

# %% [markdown]
# ## Test with a example sample

# %%
sample_test= """<?xml version="1.0"?>
<rdf:RDF xmlns="http://edamontology.org/"
     xml:base="http://edamontology.org/"
     xmlns:dc="http://purl.org/dc/elements/1.1/"
     xmlns:dcterms="http://purl.org/dc/terms/"
     xmlns:owl="http://www.w3.org/2002/07/owl#"
     xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
     xmlns:xml="http://www.w3.org/XML/1998/namespace"
     xmlns:xsd="http://www.w3.org/2001/XMLSchema#"
     xmlns:doap="http://usefulinc.com/ns/doap#"
     xmlns:edam="http://purl.obolibrary.org/obo/edam#"
     xmlns:foaf="http://xmlns.com/foaf/0.1/"
     xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
     xmlns:oboInOwl="http://www.geneontology.org/formats/oboInOwl#"
     xmlns:oboOther="http://purl.obolibrary.org/obo/">

<owl:Class rdf:about="c">
    <rdfs:subClassOf rdf:resource="b"/>
</owl:Class>
<owl:Class rdf:about="d">
    <rdfs:subClassOf rdf:resource="b"/>
</owl:Class>   
<owl:Class rdf:about="b">
    <rdfs:subClassOf rdf:resource="a"/>
</owl:Class>

<owl:Class rdf:about="a">
    <rdfs:subClassOf>
    <owl:Restriction>
        <owl:onProperty rdf:resource="http://edamontology.org/is_format_of"/>
        <owl:someValuesFrom rdf:resource="data"/>
    </owl:Restriction>
    </rdfs:subClassOf>
</owl:Class>
</rdf:RDF>
"""

# %%
q = """
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX oboInOwl: <http://www.geneontology.org/formats/oboInOwl#>
PREFIX edam:<http://edamontology.org/>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

CONSTRUCT { 
    # ?children_format rdfs:subClassOf ?restriction . 
    # ?restriction rdf:type owl:Restriction ; 
            owl:onProperty edam:is_format_of  ; 
            owl:someValuesFrom ?data. 
}
WHERE {
    # ?parent_format rdfs:subClassOf ?restriction . 
    # ?restriction rdf:type owl:Restriction ; 
            owl:onProperty edam:is_format_of  ; 
            owl:someValuesFrom ?data.
    # ?children_format rdfs:subClassOf* ?parent_format .
    }
    
    
"""

# %%
g2 = ConjunctiveGraph()
g2.parse(data=sample_test, format="xml")
print(len(g2))
# Out:
# 11

# %%
results = g2.query(q)
print(f"{len(results)} ")
for r in results:
    print(r[0],r[1],r[2])
# Out:
# 7
# Ne9b0bdaaafb34c71990f41cc75d45281 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#Restriction
# http://edamontology.org/c http://www.w3.org/2000/01/rdf-schema#subClassOf Ne9b0bdaaafb34c71990f41cc75d45281
# Ne9b0bdaaafb34c71990f41cc75d45281 http://www.w3.org/2002/07/owl#onProperty http://edamontology.org/is_format_of
# http://edamontology.org/a http://www.w3.org/2000/01/rdf-schema#subClassOf Ne9b0bdaaafb34c71990f41cc75d45281
# Ne9b0bdaaafb34c71990f41cc75d45281 http://www.w3.org/2002/07/owl#someValuesFrom http://edamontology.org/data
# http://edamontology.org/d http://www.w3.org/2000/01/rdf-schema#subClassOf Ne9b0bdaaafb34c71990f41cc75d45281
# http://edamontology.org/b http://www.w3.org/2000/01/rdf-schema#subClassOf Ne9b0bdaaafb34c71990f41cc75d45281
